# %%
import pandas as pd
import itertools
from itertools import product
import re
import sys
from collections import defaultdict, deque
from tqdm import tqdm
import numpy as np
import copy
import csv

# %%
ROOT = "../"
DATA  = ROOT + "datasets/"
MODELS = ROOT + "models/"

# %%
class CPT:
    def __init__(self, head, parents):
        self.head = head
        self.parents = parents
        self.entries = {}

    def __str__(self):
        comma = ", "
        if len(self.parents) == 0:
            return f"probability ( {self.head.name} ) {{" + "\n" \
                f"  table {comma.join ( map(str,self.entries[tuple()].values () ))};" + "\n" \
                f"}}" + "\n"
        else:
            return f"probability ( {self.head.name} | {comma.join ( [p.name for p in self.parents ] )} ) {{" + "\n" + \
                "\n".join ( [  \
                    f"  ({comma.join(names)}) {comma.join(map(str,values.values ()))};" \
                    for names,values in self.entries.items () \
                ] ) + "\n}\n"

# %%
class Variable:
    def __init__(self, name, values):
        self.name = name
        self.values = values 
        self.cpt = None

    def __str__(self):
        comma = ", "
        return f"variable {self.name} {{" + "\n" \
             + f"  type discrete [ {len(self.values)} ] {{ {(comma.join(self.values))} }};" + "\n" \
             + f"}}" + "\n"

# %%
class BayesianNetwork:
    def __init__(self, input_file):
        with open(input_file) as f:
            lines = f.readlines()
        self.variables = {}
        for i in range(len(lines)):
            lines[i] = lines[i].lstrip().rstrip().replace('/', '-')
        i = 0
        while i < len(lines) and not lines[i].startswith("probability"):
            if lines[i].startswith("variable"):
                variable_name = lines[i].rstrip().split(' ')[1]
                i += 1
                variable_def = lines[i].rstrip().split(' ')
                assert(variable_def[1] == 'discrete')
                variable_values = [x for x in variable_def[6:-1]]
                for j in range(len(variable_values)):
                    variable_values[j] = re.sub(r'\(|\)|,', '', variable_values[j])
                variable = Variable(variable_name, variable_values)
                self.variables[variable_name] = variable
            i += 1
        while i < len(lines):
            if lines[i].startswith('probability'):
                split = lines[i].split(' ')
                target_variable_name = split[2]
                variable = self.variables[target_variable_name]
                parents = [self.variables[x.rstrip().lstrip().replace(',', '')] for x in split[4:-2]]
                assert(variable.name == split[2])
                cpt = CPT(variable, parents)
                i += 1
                if len(parents) > 0:
                    nb_lines = 1
                    for p in parents:
                        nb_lines *= len(p.values)
                    for _ in range(nb_lines):
                        cpt_line = [x for x in re.sub(r'\(|\)|,', '', lines[i][:-1]).split()]
                        parent_values = tuple([x for x in cpt_line[:len(parents)]])
                        probabilities = [float(p) for p in cpt_line[len(parents):]]
                        cpt.entries[parent_values] = { v:p for v,p in zip(variable.values,probabilities) }
                        i += 1
                else:
                    cpt_line = [x for x in re.sub(r'\(|\)|,', '', lines[i][:-1]).split()]
                    probabilities = [float(p) for p in cpt_line[1:]]
                    cpt.entries[tuple()] = { v:p for v,p in zip(variable.values,probabilities) }
                variable.cpt = cpt
            i += 1

    def learn_parameters(self, csv_file, laplace_smoothing=True):
        # # Probabilités marginales (si la variable Y n'a pas de parents) :
        # P(Y = y) = count(Y = y) / total_count

        # Probabilités conditionnelles (si Y a des parents X1, X2, ..., Xn) :
        # P(Y = y | X1 = x1, X2 = x2, ..., Xn = xn) = count(Y = y AND X1 = x1 AND ... AND Xn = xn) / count(X1 = x1 AND ... AND Xn = xn)

        # Avec lissage de Laplace (alpha = 1) :
        # P(Y = y | parents) = (count(Y = y, parents) + alpha) / (count(parents) + alpha * K)

        # où :
        # - alpha = 1 (pour le lissage)
        # - K = nombre de valeurs possibles pour Y

        alpha = 1 if laplace_smoothing else 0

        for var in self.variables.values():
            if var.cpt is None:
                var.cpt = CPT(var, [])  # in case CPT is missing

        with open(csv_file, "r") as f:
            reader = csv.DictReader(f)
            data = list(reader)

        for var_name, var in self.variables.items():

            if var.cpt is None:
                continue

            parents = var.cpt.parents
            cpt = {}

            parent_names = []
            for p in parents:
                parent_names.append(p.name)

            parent_value_combinations = []
            parent_values = []
            for p in parent_names:
                parent_values.append(self.variables[p].values)
            
            parent_value_combinations = list(itertools.product(*parent_values))

            for parent_vals in parent_value_combinations:
                parent_vals = tuple(parent_vals)

                counts = {}
                for v in var.values:
                    counts[v] = 0
                total = 0

                # Count occurrences in the data
                for row in data:
                    # Check if this row matches our parent value combination
                    match = True
                    for i in range(len(parent_names)):
                        p = parent_names[i]
                        val = parent_vals[i]
                        if row[p] != val:
                            match = False
                            break
                    
                    # If all parent values match, count this instance
                    if match:
                        y_val = row[var_name]
                        if y_val in counts:
                            counts[y_val] += 1
                            total += 1


                smoothed_total = total + alpha * len(var.values)
                probs = {}
                for v in var.values:
                    probs[v] = (counts[v] + alpha) / smoothed_total
                cpt[parent_vals] = probs

            if not parents:
                counts = {}
                for v in var.values:
                    counts[v] = 0
                total = 0

                for row in data:
                    y_val = row[var_name]
                    if y_val in counts:
                        counts[y_val] += 1
                        total += 1
                smoothed_total = total + alpha * len(var.values)

                probs = {}
                for v in var.values:
                    probs[v] = (counts[v] + alpha) / smoothed_total

                cpt[tuple()] = probs

            var.cpt.entries = cpt


    def write(self,filename):
        with open(filename,"w") as file:
            for var in self.variables.values ():
                file.write(str(var))
            for var in self.variables.values ():
                file.write(str(var.cpt))

    def P_Yisy_given_parents_x(self,Y,y,x=tuple()):
        return self.variables[Y].cpt.entries[x][y]

    def P_Yisy_given_parents(self,Y,y,pa={}):
        x = tuple([ pa[parent.name] for parent in self.variables[Y].cpt.parents ])
        return self.P_Yisy_given_parents_x(Y,y,x)

    def _get_children(self):
        children = defaultdict(list)
        for var in self.variables.values():
            for parent in var.cpt.parents:
                children[parent.name].append(var.name)
        return children

    def _normalize(self, dist):
        total = sum(dist.values())
        return {k: v / total for k, v in dist.items() if total > 0}

    def _get_pi_contribution(self, pname, pval, pi_msgs, evidence):
        if pname in pi_msgs:
            return pi_msgs[pname][pval]
        elif pname in evidence:
            return 1.0 if evidence[pname] == pval else 0.0
        else:
            return 1.0 / len(self.variables[pname].values)

    def _send_messages_to_root(self, node, evidence, children, lambda_msgs):
        if node in lambda_msgs:
            return lambda_msgs[node]

        var = self.variables[node]
        lambda_msg = {val: 1.0 for val in var.values}

        for child in children[node]:
            child_lambda = self._send_messages_to_root(child, evidence, children, lambda_msgs)
            child_var = self.variables[child]
            parent_names = [p.name for p in child_var.cpt.parents]

            new_lambda = {}
            for xi in var.values:
                msg = 0.0
                for xj in child_var.values:
                    def get_vals(pname):
                        if pname == node:
                            return [xi]
                        elif pname in evidence:
                            return [evidence[pname]]
                        else:
                            return self.variables[pname].values

                    all_pa_vals = itertools.product(*[get_vals(pname) for pname in parent_names])

                    for pa in all_pa_vals:
                        pa_dict = dict(zip(parent_names, pa))
                        pa_vals = tuple(pa_dict[p.name] for p in child_var.cpt.parents)
                        prob = child_var.cpt.entries[pa_vals][xj]
                        msg += prob * child_lambda[xj]
                new_lambda[xi] = lambda_msg[xi] * msg
            lambda_msg = new_lambda

        if node in evidence:
            observed = evidence[node]
            lambda_msg = {val: (1.0 if val == observed else 0.0) for val in var.values}

        lambda_msgs[node] = lambda_msg
        return lambda_msg

    def _send_messages_from_root(self, node, pi_msg, evidence, children, lambda_msgs, beliefs, pi_msgs):
        var = self.variables[node]
        lambda_msg = lambda_msgs[node]
        belief = {val: pi_msg[val] * lambda_msg[val] for val in var.values}
        beliefs[node] = self._normalize(belief)
        pi_msgs[node] = pi_msg

        for child in children[node]:
            child_var = self.variables[child]
            parent_names = [p.name for p in child_var.cpt.parents]
            child_pi = {xj: 0.0 for xj in child_var.values}

            for xj in child_var.values:
                total = 0.0
                def get_vals(pname):
                    if pname in evidence:
                        return [evidence[pname]]
                    else:
                        return self.variables[pname].values

                all_pa_vals = itertools.product(*[get_vals(pname) for pname in parent_names])

                for pa in all_pa_vals:
                    pa_dict = dict(zip(parent_names, pa))
                    pa_vals = tuple(pa_dict[p.name] for p in child_var.cpt.parents)
                    prob = child_var.cpt.entries[pa_vals][xj]

                    contrib = 1.0
                    for pname, pval in pa_dict.items():
                        contrib *= self._get_pi_contribution(pname, pval, pi_msgs, evidence)

                    total += contrib * prob

                child_pi[xj] = total

            self._send_messages_from_root(child, child_pi, evidence, children, lambda_msgs, beliefs, pi_msgs)

    def query_marginal(self, query_var, evidence):
        children = self._get_children()
        lambda_msgs = {}
        beliefs = {}
        pi_msgs = {}
        root = next(iter(evidence)) if evidence else query_var
        self._send_messages_to_root(root, evidence, children, lambda_msgs)
        root_var = self.variables[root]
        if root_var.cpt.parents:
            root_pi = {val: 1.0 for val in root_var.values}
        else:
            root_pi = root_var.cpt.entries[tuple()]
        self._send_messages_from_root(root, root_pi, evidence, children, lambda_msgs, beliefs, pi_msgs)
        if query_var not in beliefs:
            self._send_messages_to_root(query_var, evidence, children, lambda_msgs)
            if self.variables[query_var].cpt.parents:
                root_pi = {val: 1.0 for val in self.variables[query_var].values}
            else:
                root_pi = self.variables[query_var].cpt.entries[tuple()]
            self._send_messages_from_root(query_var, root_pi, evidence, children, lambda_msgs, beliefs, pi_msgs)

        return beliefs[query_var]
    
    def query_joint(self, var1, var2, evidence):
        joint_dist = {}
        for val1 in self.variables[var1].values:
            joint_dist[val1] = {}
            for val2 in self.variables[var2].values:
                extended_evidence = dict(evidence)
                extended_evidence[var1] = val1
                extended_evidence[var2] = val2
                marg = self.query_marginal(var2, evidence)
                if var2 not in marg or val2 not in marg:
                    marg = self.query_marginal(var2, evidence)
                if val2 not in marg:
                    continue
                cond = self.query_marginal(var1, {**evidence, var2: val2})
                if var1 not in cond or val1 not in cond:
                    cond = self.query_marginal(var1, {**evidence, var2: val2})
                joint_dist[val1][val2] = cond[val1] * marg[val2]
        return self._normalize_nested(joint_dist)

    def _normalize_nested(self, joint_dist):
        total = sum(v for d in joint_dist.values() for v in d.values())
        if total == 0:
            return joint_dist
        for k1 in joint_dist:
            for k2 in joint_dist[k1]:
                joint_dist[k1][k2] /= total
        return joint_dist

# %%
def _clean_missing_dataframe(df):
    """
    Clean the missing-value dataframe:
    - Replace "?" with NA
    - Convert all non-missing values to stringified integers
    """
    df = df.replace("?", pd.NA)
    for col in df.columns:
        df[col] = df[col].apply(lambda x: str(int(float(x))) if pd.notna(x) else pd.NA)
    return df

# %%
def evaluate_network(network_path_file, test_dataset_path, miss_dataset_path, verbose=False):
    bn = BayesianNetwork(network_path_file)

    test_df = pd.read_csv(test_dataset_path)
    miss_df = pd.read_csv(miss_dataset_path)
    miss_df = _clean_missing_dataframe(miss_df)

    correct = 0
    total = 0
    confidences = []
    row_logs = [] if verbose else None

    iterator = tqdm(range(len(miss_df)), desc="Evaluating") if verbose else range(len(miss_df))

    for i in iterator:
        evidence = miss_df.iloc[i].dropna().to_dict()
        ground_truth = test_df.iloc[i].to_dict()
        missing_vars = [col for col in miss_df.columns if pd.isna(miss_df.iloc[i][col])]

        for var in missing_vars:
            predicted_dist = bn.query_marginal(var, evidence)
            if not predicted_dist:
                continue

            predicted_val = max(predicted_dist, key=predicted_dist.get)
            confidence = predicted_dist[predicted_val]
            confidences.append(confidence)

            is_correct = (predicted_val == str(ground_truth[var]))
            correct += is_correct
            total += 1
            if verbose and not is_correct:
                row_logs.append(
                    f"[Row {i}] {var} predicted: {predicted_val} (conf: {confidence:.2f}), true: {ground_truth[var]}"
                )


    accuracy = correct / total if total > 0 else 0.0
    avg_confidence = sum(confidences) / len(confidences) if confidences else 0.0

    if verbose:
        print(f"\nMismatches ({len(row_logs)}):")
        print("\n".join(row_logs))
        print(f"\nFinal Accuracy: {accuracy:.4f}")
        print(f"Average Confidence: {avg_confidence:.4f}")

    return accuracy, avg_confidence

# %%
data = "alarm"
evaluate_network(
    MODELS + f"{data}/{data}_complete.bif",
    DATA + f"{data}/test.csv",
    DATA + f"{data}/test_missing.csv",
    verbose=True
)
# Out:
# Evaluating: 100%|██████████| 2000/2000 [00:03<00:00, 656.40it/s]
# Mismatches (466):
# [Row 1] EXPCO2 predicted: 0 (conf: 0.25), true: 2
# [Row 2] CO predicted: 0 (conf: 0.89), true: 1
# [Row 3] BP predicted: 2 (conf: 0.75), true: 0
# [Row 9] HRBP predicted: 0 (conf: 0.33), true: 2
# [Row 10] ARTCO2 predicted: 1 (conf: 0.50), true: 2
# [Row 15] PRESS predicted: 0 (conf: 0.25), true: 3
# [Row 17] EXPCO2 predicted: 0 (conf: 0.25), true: 1
# [Row 21] VENTMACH predicted: 0 (conf: 0.33), true: 2
# [Row 26] MINVOL predicted: 0 (conf: 0.25), true: 3
# [Row 28] PAP predicted: 0 (conf: 0.33), true: 1
# [Row 33] EXPCO2 predicted: 0 (conf: 0.25), true: 1
# [Row 33] PAP predicted: 0 (conf: 0.33), true: 1
# [Row 34] CVP predicted: 2 (conf: 0.70), true: 1
# [Row 34] PRESS predicted: 0 (conf: 0.25), true: 3
# [Row 40] EXPCO2 predicted: 0 (conf: 0.25), true: 1
# [Row 51] FIO2 predicted: 1 (conf: 0.95), true: 0
# [Row 52] EXPCO2 predicted: 0 (conf: 0.25), true: 1
# [Row 54] HREKG predicted: 0 (conf: 0.33), true: 2
# [Row 63] HRBP predicted: 0 (conf: 0.33), true: 2
# [Row 64] VENTMACH predicted: 0 (conf: 0.33), true: 2
# [Row 65] HRBP predicted: 0 (conf: 0.33), true: 2
# [Row 67] INSUFFANESTH predicted: 1 (conf: 0.90), true: 0
# [Row 70] PRESS predicted: 0 (conf: 0.25), true: 1
# [Row 74] CATECHOL predicted: 0 (conf: 0.91), true: 1
# [Row 76] VENTALV predicted: 1 (conf: 0.77), true: 0
# [Row 79] HRSAT predicted: 0 (conf: 0.33), true: 2
# [Row 80] EXPCO2 predicted: 0 (conf: 0.25), true: 2
# [Row 87] HREKG predicted: 0 (conf: 0.33), true: 2
# [Row 98] HREKG predicted: 0 (conf: 0.33), true: 2
# [Row 98] EXPCO2 predicted: 0 (conf: 0.25), true: 1
# [Row 101] EXPCO2 predicted: 0 (conf: 0.25), true: 1
# [Row 102] SAO2 predicted: 0 (conf: 0.33), true: 1
# [Row 110] CO predicted: 0 (conf: 0.34), true: 2
# [Row 112] PRESS predicted: 0 (conf: 0.25), true: 2
# [Row 113] ARTCO2 predicted: 0 (conf: 0.96), true: 2
# [Row 117] EXPCO2 predicted: 0 (conf: 0.25), true: 1
# [Row 121] PAP predicted: 0 (conf: 0.33), true: 1
# [Row 126] HRSAT predicted: 0 (conf: 0.33), true: 2
# [Row 132] EXPCO2 predicted: 0 (conf: 0.25), true: 1
# [Row 133] HRBP predicted: 0 (conf: 0.33), true: 2
# [Row 135] FIO2 predicted: 1 (conf: 0.95), true: 0
# [Row 140] ERRCAUTER predicted: 1 (conf: 0.90), true: 0
# [Row 143] HYPOVOLEMIA predicted: 0 (conf: 0.71), true: 1
# [Row 145] CATECHOL predicted: 0 (conf: 0.91), true: 1
# [Row 146] PRESS predicted: 0 (conf: 0.25), true: 1
# [Row 149] HRBP predicted: 0 (conf: 0.33), true: 2
# [Row 153] HRBP predicted: 0 (conf: 0.33), true: 1
# [Row 164] PAP predicted: 0 (conf: 0.33), true: 1
# [Row 167] SHUNT predicted: 0 (conf: 0.50), true: 1
# [Row 168] EXPCO2 predicted: 0 (conf: 0.25), true: 1
# [Row 176] HREKG predicted: 0 (conf: 0.33), true: 2
# [Row 179] PAP predicted: 0 (conf: 0.33), true: 1
# [Row 189] PRESS predicted: 0 (conf: 0.25), true: 2
# [Row 192] HRSAT predicted: 0 (conf: 0.33), true: 2
# [Row 195] PRESS predicted: 0 (conf: 0.25), true: 3
# [Row 204] HRBP predicted: 0 (conf: 0.33), true: 2
# [Row 205] HREKG predicted: 0 (conf: 0.33), true: 2
# [Row 206] EXPCO2 predicted: 0 (conf: 0.25), true: 1
# [Row 206] VENTMACH predicted: 0 (conf: 0.33), true: 2
# [Row 207] MINVOL predicted: 0 (conf: 0.25), true: 3
# [Row 208] PRESS predicted: 0 (conf: 0.25), true: 3
# [Row 214] HRBP predicted: 0 (conf: 0.33), true: 2
# [Row 221] HYPOVOLEMIA predicted: 1 (conf: 0.99), true: 0
# [Row 230] HREKG predicted: 0 (conf: 0.33), true: 2
# [Row 233] HREKG predicted: 0 (conf: 0.33), true: 2
# [Row 233] VENTTUBE predicted: 1 (conf: 0.56), true: 0
# [Row 234] HREKG predicted: 0 (conf: 0.33), true: 2
# [Row 241] INSUFFANESTH predicted: 1 (conf: 0.90), true: 0
# [Row 244] STROKEVOLUME predicted: 0 (conf: 0.57), true: 1
# [Row 244] CATECHOL predicted: 0 (conf: 0.91), true: 1
# [Row 245] SAO2 predicted: 0 (conf: 0.33), true: 2
# [Row 252] HRBP predicted: 0 (conf: 0.33), true: 2
# [Row 253] EXPCO2 predicted: 0 (conf: 0.25), true: 1
# [Row 256] INSUFFANESTH predicted: 1 (conf: 0.90), true: 0
# [Row 264] HRSAT predicted: 0 (conf: 0.33), true: 2
# [Row 267] PAP predicted: 0 (conf: 0.33), true: 1
# [Row 272] EXPCO2 predicted: 0 (conf: 0.25), true: 1
# [Row 279] PAP predicted: 0 (conf: 0.33), true: 2
# [Row 298] BP predicted: 0 (conf: 0.33), true: 2
# [Row 300] PRESS predicted: 0 (conf: 0.25), true: 3
# [Row 301] HRBP predicted: 0 (conf: 0.33), true: 2
# [Row 302] HREKG predicted: 0 (conf: 0.33), true: 2
# [Row 302] PAP predicted: 0 (conf: 0.33), true: 1
# [Row 308] EXPCO2 predicted: 0 (conf: 0.25), true: 1
# [Row 314] VENTTUBE predicted: 1 (conf: 0.56), true: 0
# [Row 323] HRBP predicted: 0 (conf: 0.33), true: 2
# [Row 325] TPR predicted: 2 (conf: 0.52), true: 1
# [Row 332] EXPCO2 predicted: 0 (conf: 0.25), true: 1
# [Row 334] CVP predicted: 0 (conf: 0.33), true: 2
# [Row 341] VENTMACH predicted: 0 (conf: 0.49), true: 1
# [Row 342] HREKG predicted: 0 (conf: 0.33), true: 2
# [Row 343] EXPCO2 predicted: 0 (conf: 0.25), true: 1
# [Row 349] TPR predicted: 2 (conf: 0.52), true: 1
# [Row 353] HRSAT predicted: 0 (conf: 0.33), true: 2
# [Row 368] HRSAT predicted: 0 (conf: 0.33), true: 2
# [Row 371] ERRCAUTER predicted: 0 (conf: 0.56), true: 1
# [Row 372] HRSAT predicted: 0 (conf: 0.33), true: 2
# [Row 373] TPR predicted: 0 (conf: 0.49), true: 1
# [Row 377] BP predicted: 2 (conf: 0.75), true: 1
# [Row 381] HRBP predicted: 0 (conf: 0.33), true: 2
# [Row 384] ARTCO2 predicted: 1 (conf: 0.50), true: 2
# [Row 386] PAP predicted: 0 (conf: 0.33), true: 1
# [Row 398] INSUFFANESTH predicted: 1 (conf: 0.90), true: 0
# [Row 405] ARTCO2 predicted: 0 (conf: 0.98), true: 2
# [Row 405] VENTALV predicted: 2 (conf: 0.50), true: 0
# [Row 415] HRBP predicted: 0 (conf: 0.33), true: 2
# [Row 417] HRSAT predicted: 0 (conf: 0.33), true: 2
# [Row 420] PAP predicted: 0 (conf: 0.33), true: 2
# [Row 429] HRBP predicted: 0 (conf: 0.33), true: 2
# [Row 433] CVP predicted: 1 (conf: 0.95), true: 0
# [Row 434] HRBP predicted: 0 (conf: 0.33), true: 2
# [Row 438] HRSAT predicted: 0 (conf: 0.33), true: 2
# [Row 439] TPR predicted: 2 (conf: 0.89), true: 1
# [Row 442] PAP predicted: 0 (conf: 0.33), true: 1
# [Row 454] EXPCO2 predicted: 0 (conf: 0.25), true: 1
# [Row 456] INSUFFANESTH predicted: 1 (conf: 0.90), true: 0
# [Row 456] CO predicted: 1 (conf: 0.94), true: 0
# [Row 457] HRSAT predicted: 0 (conf: 0.33), true: 2
# [Row 457] TPR predicted: 2 (conf: 0.52), true: 1
# [Row 460] PAP predicted: 0 (conf: 0.33), true: 2
# [Row 467] HRBP predicted: 0 (conf: 0.33), true: 2
# [Row 469] ARTCO2 predicted: 1 (conf: 0.50), true: 2
# [Row 472] HREKG predicted: 0 (conf: 0.33), true: 2
# [Row 476] PRESS predicted: 0 (conf: 0.25), true: 3
# [Row 479] CVP predicted: 1 (conf: 0.95), true: 0
# [Row 481] HRSAT predicted: 0 (conf: 0.33), true: 2
# [Row 482] ARTCO2 predicted: 1 (conf: 0.50), true: 2
# [Row 493] TPR predicted: 0 (conf: 0.37), true: 1
# [Row 494] SAO2 predicted: 1 (conf: 0.37), true: 2
# [Row 503] HREKG predicted: 0 (conf: 0.33), true: 2
# [Row 508] EXPCO2 predicted: 0 (conf: 0.25), true: 2
# [Row 509] MINVOL predicted: 0 (conf: 0.25), true: 3
# [Row 511] HREKG predicted: 0 (conf: 0.33), true: 2
# [Row 515] EXPCO2 predicted: 0 (conf: 0.25), true: 1
# [Row 519] HREKG predicted: 0 (conf: 0.33), true: 2
# [Row 519] HRSAT predicted: 0 (conf: 0.33), true: 2
# [Row 524] INSUFFANESTH predicted: 1 (conf: 0.90), true: 0
# [Row 530] MINVOL predicted: 0 (conf: 0.25), true: 3
# [Row 535] TPR predicted: 0 (conf: 0.44), true: 1
# [Row 536] TPR predicted: 2 (conf: 0.52), true: 1
# [Row 536] PAP predicted: 0 (conf: 0.33), true: 1
# [Row 542] EXPCO2 predicted: 0 (conf: 0.25), true: 1
# [Row 542] BP predicted: 2 (conf: 0.75), true: 1
# [Row 543] PRESS predicted: 0 (conf: 0.25), true: 3
# [Row 546] ARTCO2 predicted: 1 (conf: 0.50), true: 2
# [Row 554] CATECHOL predicted: 0 (conf: 0.91), true: 1
# [Row 560] SAO2 predicted: 0 (conf: 0.34), true: 2
# [Row 562] HYPOVOLEMIA predicted: 1 (conf: 0.98), true: 0
# [Row 564] HRSAT predicted: 0 (conf: 0.33), true: 2
# [Row 566] HR predicted: 0 (conf: 0.85), true: 2
# [Row 570] STROKEVOLUME predicted: 1 (conf: 0.95), true: 2
# [Row 571] INSUFFANESTH predicted: 1 (conf: 0.90), true: 0
# [Row 579] ARTCO2 predicted: 2 (conf: 0.51), true: 1
# [Row 581] PRESS predicted: 0 (conf: 0.25), true: 2
# [Row 583] PRESS predicted: 0 (conf: 0.25), true: 1
# [Row 586] EXPCO2 predicted: 0 (conf: 0.25), true: 1
# [Row 587] CATECHOL predicted: 0 (conf: 0.91), true: 1
# [Row 593] HREKG predicted: 0 (conf: 0.33), true: 2
# [Row 595] HREKG predicted: 0 (conf: 0.33), true: 2
# [Row 596] HRBP predicted: 0 (conf: 0.33), true: 2
# [Row 596] HREKG predicted: 0 (conf: 0.33), true: 2
# [Row 597] STROKEVOLUME predicted: 2 (conf: 0.51), true: 1
# [Row 622] PRESS predicted: 0 (conf: 0.25), true: 3
# [Row 623] PAP predicted: 0 (conf: 0.33), true: 1
# [Row 626] PRESS predicted: 0 (conf: 0.25), true: 3
# [Row 634] HREKG predicted: 0 (conf: 0.33), true: 2
# [Row 637] CO predicted: 1 (conf: 0.65), true: 2
# [Row 639] TPR predicted: 1 (conf: 0.54), true: 2
# [Row 640] PRESS predicted: 0 (conf: 0.25), true: 2
# [Row 641] HREKG predicted: 0 (conf: 0.33), true: 2
# [Row 642] EXPCO2 predicted: 0 (conf: 0.25), true: 1
# [Row 645] HYPOVOLEMIA predicted: 1 (conf: 0.53), true: 0
# [Row 658] MINVOL predicted: 0 (conf: 0.25), true: 2
# [Row 674] HRSAT predicted: 0 (conf: 0.33), true: 2
# [Row 685] SHUNT predicted: 0 (conf: 0.50), true: 1
# [Row 688] STROKEVOLUME predicted: 1 (conf: 0.95), true: 2
# [Row 688] HRBP predicted: 0 (conf: 0.33), true: 2
# [Row 689] ARTCO2 predicted: 1 (conf: 0.87), true: 2
# [Row 690] VENTALV predicted: 0 (conf: 0.50), true: 1
# [Row 704] HRSAT predicted: 0 (conf: 0.33), true: 1
# [Row 705] CVP predicted: 0 (conf: 0.95), true: 1
# [Row 705] HRSAT predicted: 0 (conf: 0.33), true: 2
# [Row 715] HRBP predicted: 0 (conf: 0.33), true: 2
# [Row 723] SAO2 predicted: 0 (conf: 0.33), true: 1
# [Row 729] HREKG predicted: 0 (conf: 0.33), true: 2
# [Row 742] HRSAT predicted: 0 (conf: 0.33), true: 2
# [Row 745] PRESS predicted: 0 (conf: 0.25), true: 1
# [Row 753] VENTTUBE predicted: 1 (conf: 0.56), true: 0
# [Row 754] HRSAT predicted: 0 (conf: 0.33), true: 1
# [Row 771] EXPCO2 predicted: 0 (conf: 0.25), true: 1
# [Row 773] HRSAT predicted: 0 (conf: 0.33), true: 2
# [Row 775] INSUFFANESTH predicted: 1 (conf: 0.90), true: 0
# [Row 778] MINVOL predicted: 0 (conf: 0.25), true: 3
# [Row 779] STROKEVOLUME predicted: 1 (conf: 0.56), true: 0
# [Row 780] MINVOL predicted: 0 (conf: 0.25), true: 3
# [Row 793] HRSAT predicted: 0 (conf: 0.33), true: 1
# [Row 799] ARTCO2 predicted: 1 (conf: 0.50), true: 2
# [Row 804] SAO2 predicted: 1 (conf: 0.37), true: 2
# [Row 812] PRESS predicted: 0 (conf: 0.25), true: 3
# [Row 814] HREKG predicted: 0 (conf: 0.33), true: 2
# [Row 826] HREKG predicted: 0 (conf: 0.33), true: 2
# [Row 833] TPR predicted: 2 (conf: 0.52), true: 1
# [Row 856] ARTCO2 predicted: 0 (conf: 0.98), true: 1
# [Row 856] SHUNT predicted: 0 (conf: 0.50), true: 1
# [Row 866] PRESS predicted: 0 (conf: 0.25), true: 3
# [Row 868] MINVOL predicted: 0 (conf: 0.25), true: 3
# [Row 871] HRSAT predicted: 0 (conf: 0.33), true: 2
# [Row 872] ERRCAUTER predicted: 0 (conf: 1.00), true: 1
# [Row 878] VENTMACH predicted: 0 (conf: 0.49), true: 1
# [Row 892] HRBP predicted: 0 (conf: 0.33), true: 2
# [Row 892] PAP predicted: 0 (conf: 0.33), true: 2
# [Row 894] VENTALV predicted: 0 (conf: 0.50), true: 1
# [Row 896] PAP predicted: 0 (conf: 0.33), true: 1
# [Row 900] PRESS predicted: 0 (conf: 0.25), true: 3
# [Row 904] HRBP predicted: 0 (conf: 0.33), true: 2
# [Row 908] HRSAT predicted: 0 (conf: 0.33), true: 2
# [Row 909] TPR predicted: 2 (conf: 0.52), true: 1
# [Row 910] CO predicted: 0 (conf: 0.86), true: 1
# [Row 913] CVP predicted: 2 (conf: 0.70), true: 1
# [Row 914] HRBP predicted: 0 (conf: 0.33), true: 2
# [Row 925] HREKG predicted: 0 (conf: 0.33), true: 2
# [Row 930] PRESS predicted: 0 (conf: 0.25), true: 3
# [Row 931] VENTMACH predicted: 0 (conf: 0.49), true: 2
# [Row 935] FIO2 predicted: 1 (conf: 0.95), true: 0
# [Row 936] PRESS predicted: 0 (conf: 0.25), true: 2
# [Row 942] ARTCO2 predicted: 0 (conf: 0.33), true: 2
# [Row 942] EXPCO2 predicted: 0 (conf: 0.25), true: 2
# [Row 945] HREKG predicted: 0 (conf: 0.33), true: 2
# [Row 946] TPR predicted: 0 (conf: 0.44), true: 1
# [Row 947] PRESS predicted: 0 (conf: 0.25), true: 1
# [Row 948] PRESS predicted: 0 (conf: 0.25), true: 2
# [Row 952] HREKG predicted: 0 (conf: 0.33), true: 2
# [Row 959] EXPCO2 predicted: 0 (conf: 0.25), true: 1
# [Row 960] HRSAT predicted: 0 (conf: 0.33), true: 2
# [Row 962] ARTCO2 predicted: 0 (conf: 0.33), true: 2
# [Row 963] SHUNT predicted: 0 (conf: 0.50), true: 1
# [Row 969] HRSAT predicted: 0 (conf: 0.33), true: 2
# [Row 971] CO predicted: 2 (conf: 0.80), true: 1
# [Row 973] HREKG predicted: 0 (conf: 0.33), true: 2
# [Row 973] VENTALV predicted: 1 (conf: 0.77), true: 0
# [Row 978] HREKG predicted: 0 (conf: 0.33), true: 2
# [Row 980] HRSAT predicted: 0 (conf: 0.33), true: 2
# [Row 981] ARTCO2 predicted: 1 (conf: 0.50), true: 2
# [Row 984] EXPCO2 predicted: 0 (conf: 0.25), true: 1
# [Row 989] HRSAT predicted: 0 (conf: 0.33), true: 2
# [Row 998] HRSAT predicted: 0 (conf: 0.33), true: 2
# [Row 998] TPR predicted: 1 (conf: 0.72), true: 2
# [Row 1000] TPR predicted: 2 (conf: 0.52), true: 1
# [Row 1003] PRESS predicted: 0 (conf: 0.25), true: 3
# [Row 1010] PRESS predicted: 0 (conf: 0.25), true: 3
# [Row 1012] INSUFFANESTH predicted: 1 (conf: 0.90), true: 0
# [Row 1022] HRBP predicted: 0 (conf: 0.33), true: 2
# [Row 1029] EXPCO2 predicted: 0 (conf: 0.25), true: 1
# [Row 1030] PAP predicted: 0 (conf: 0.33), true: 1
# [Row 1043] PRESS predicted: 0 (conf: 0.25), true: 3
# [Row 1044] HRSAT predicted: 0 (conf: 0.33), true: 2
# [Row 1045] TPR predicted: 2 (conf: 0.52), true: 1
# [Row 1050] PAP predicted: 0 (conf: 0.33), true: 2
# [Row 1053] EXPCO2 predicted: 0 (conf: 0.25), true: 1
# [Row 1058] HRSAT predicted: 0 (conf: 0.33), true: 2
# [Row 1058] PAP predicted: 0 (conf: 0.33), true: 1
# [Row 1071] EXPCO2 predicted: 0 (conf: 0.25), true: 1
# [Row 1087] MINVOL predicted: 0 (conf: 0.25), true: 3
# [Row 1097] HREKG predicted: 0 (conf: 0.33), true: 2
# [Row 1100] HRBP predicted: 0 (conf: 0.33), true: 2
# [Row 1118] EXPCO2 predicted: 0 (conf: 0.25), true: 1
# [Row 1121] EXPCO2 predicted: 0 (conf: 0.25), true: 1
# [Row 1124] VENTALV predicted: 1 (conf: 0.77), true: 0
# [Row 1126] HREKG predicted: 0 (conf: 0.33), true: 2
# [Row 1131] TPR predicted: 1 (conf: 0.51), true: 2
# [Row 1133] MINVOL predicted: 0 (conf: 0.25), true: 3
# [Row 1138] ARTCO2 predicted: 0 (conf: 0.33), true: 2
# [Row 1141] EXPCO2 predicted: 0 (conf: 0.25), true: 2
# [Row 1144] HRBP predicted: 0 (conf: 0.33), true: 2
# [Row 1144] EXPCO2 predicted: 0 (conf: 0.25), true: 1
# [Row 1146] SHUNT predicted: 0 (conf: 0.50), true: 1
# [Row 1149] HRBP predicted: 0 (conf: 0.33), true: 2
# [Row 1154] EXPCO2 predicted: 0 (conf: 0.25), true: 1
# [Row 1155] STROKEVOLUME predicted: 1 (conf: 0.78), true: 0
# [Row 1155] PAP predicted: 0 (conf: 0.33), true: 1
# [Row 1165] PAP predicted: 0 (conf: 0.33), true: 1
# [Row 1166] PRESS predicted: 0 (conf: 0.25), true: 1
# [Row 1169] HRSAT predicted: 0 (conf: 0.33), true: 1
# [Row 1171] PRESS predicted: 0 (conf: 0.25), true: 3
# [Row 1174] PAP predicted: 0 (conf: 0.33), true: 1
# [Row 1177] EXPCO2 predicted: 0 (conf: 0.25), true: 3
# [Row 1187] ARTCO2 predicted: 1 (conf: 0.50), true: 2
# [Row 1188] VENTTUBE predicted: 3 (conf: 0.74), true: 1
# [Row 1201] PRESS predicted: 0 (conf: 0.25), true: 3
# [Row 1205] HRSAT predicted: 0 (conf: 0.33), true: 2
# [Row 1243] SHUNT predicted: 1 (conf: 0.73), true: 0
# [Row 1245] HRBP predicted: 0 (conf: 0.33), true: 2
# [Row 1245] HRSAT predicted: 0 (conf: 0.33), true: 2
# [Row 1250] FIO2 predicted: 1 (conf: 0.95), true: 0
# [Row 1257] HYPOVOLEMIA predicted: 0 (conf: 0.71), true: 1
# [Row 1267] EXPCO2 predicted: 0 (conf: 0.25), true: 1
# [Row 1272] HRBP predicted: 0 (conf: 0.33), true: 2
# [Row 1275] PAP predicted: 0 (conf: 0.33), true: 1
# [Row 1277] VENTMACH predicted: 0 (conf: 0.33), true: 2
# [Row 1281] EXPCO2 predicted: 0 (conf: 0.25), true: 1
# [Row 1282] PAP predicted: 0 (conf: 0.33), true: 1
# [Row 1283] HRSAT predicted: 0 (conf: 0.33), true: 2
# [Row 1295] PRESS predicted: 0 (conf: 0.25), true: 3
# [Row 1300] INSUFFANESTH predicted: 1 (conf: 0.90), true: 0
# [Row 1304] EXPCO2 predicted: 0 (conf: 0.25), true: 1
# [Row 1312] HRBP predicted: 0 (conf: 0.33), true: 2
# [Row 1315] PAP predicted: 0 (conf: 0.33), true: 1
# [Row 1323] EXPCO2 predicted: 0 (conf: 0.25), true: 1
# [Row 1323] MINVOL predicted: 0 (conf: 0.25), true: 2
# [Row 1332] CATECHOL predicted: 0 (conf: 0.91), true: 1
# [Row 1337] PAP predicted: 0 (conf: 0.33), true: 1
# [Row 1341] HRBP predicted: 0 (conf: 0.33), true: 2
# [Row 1350] HRSAT predicted: 0 (conf: 0.33), true: 1
# [Row 1356] HREKG predicted: 0 (conf: 0.33), true: 2
# [Row 1357] PRESS predicted: 0 (conf: 0.25), true: 2
# [Row 1359] HREKG predicted: 0 (conf: 0.33), true: 2
# [Row 1360] SAO2 predicted: 1 (conf: 0.37), true: 2
# [Row 1380] SAO2 predicted: 0 (conf: 0.33), true: 2
# [Row 1383] EXPCO2 predicted: 0 (conf: 0.25), true: 1
# [Row 1384] CVP predicted: 1 (conf: 0.95), true: 2
# [Row 1386] EXPCO2 predicted: 0 (conf: 0.25), true: 1
# [Row 1391] HREKG predicted: 0 (conf: 0.33), true: 1
# [Row 1394] HREKG predicted: 0 (conf: 0.33), true: 1
# [Row 1397] VENTMACH predicted: 0 (conf: 0.33), true: 2
# [Row 1398] HRSAT predicted: 0 (conf: 0.33), true: 2
# [Row 1404] EXPCO2 predicted: 0 (conf: 0.25), true: 1
# [Row 1408] SAO2 predicted: 0 (conf: 0.33), true: 2
# [Row 1417] HRSAT predicted: 0 (conf: 0.33), true: 2
# [Row 1420] PRESS predicted: 0 (conf: 0.25), true: 3
# [Row 1421] PRESS predicted: 0 (conf: 0.25), true: 2
# [Row 1422] HREKG predicted: 0 (conf: 0.33), true: 2
# [Row 1429] SAO2 predicted: 1 (conf: 0.43), true: 2
# [Row 1431] PAP predicted: 0 (conf: 0.33), true: 1
# [Row 1433] TPR predicted: 0 (conf: 0.44), true: 1
# [Row 1444] STROKEVOLUME predicted: 0 (conf: 0.83), true: 1
# [Row 1450] ARTCO2 predicted: 1 (conf: 0.50), true: 2
# [Row 1462] PRESS predicted: 0 (conf: 0.25), true: 3
# [Row 1464] HRBP predicted: 0 (conf: 0.33), true: 2
# [Row 1466] LVEDVOLUME predicted: 2 (conf: 0.62), true: 1
# [Row 1471] ARTCO2 predicted: 1 (conf: 0.50), true: 2
# [Row 1476] PRESS predicted: 0 (conf: 0.25), true: 3
# [Row 1478] SHUNT predicted: 0 (conf: 0.50), true: 1
# [Row 1479] SHUNT predicted: 0 (conf: 0.50), true: 1
# [Row 1480] HREKG predicted: 0 (conf: 0.33), true: 2
# [Row 1486] HREKG predicted: 0 (conf: 0.33), true: 2
# [Row 1487] MINVOL predicted: 0 (conf: 0.25), true: 3
# [Row 1489] PAP predicted: 0 (conf: 0.33), true: 1
# [Row 1497] HRSAT predicted: 0 (conf: 0.33), true: 2
# [Row 1502] TPR predicted: 2 (conf: 0.52), true: 1
# [Row 1504] INSUFFANESTH predicted: 1 (conf: 0.90), true: 0
# [Row 1507] HRSAT predicted: 0 (conf: 0.33), true: 2
# [Row 1511] HRSAT predicted: 0 (conf: 0.33), true: 2
# [Row 1513] PAP predicted: 0 (conf: 0.33), true: 1
# [Row 1515] TPR predicted: 2 (conf: 0.52), true: 1
# [Row 1517] HISTORY predicted: 1 (conf: 0.99), true: 0
# [Row 1534] PAP predicted: 0 (conf: 0.33), true: 1
# [Row 1542] PAP predicted: 0 (conf: 0.33), true: 1
# [Row 1546] HYPOVOLEMIA predicted: 0 (conf: 0.71), true: 1
# [Row 1546] HRBP predicted: 0 (conf: 0.33), true: 2
# [Row 1553] HREKG predicted: 0 (conf: 0.33), true: 2
# [Row 1558] EXPCO2 predicted: 0 (conf: 0.25), true: 2
# [Row 1559] PRESS predicted: 0 (conf: 0.25), true: 2
# [Row 1562] HRBP predicted: 0 (conf: 0.33), true: 2
# [Row 1569] HRBP predicted: 0 (conf: 0.33), true: 2
# [Row 1570] PRESS predicted: 0 (conf: 0.25), true: 3
# [Row 1570] DISCONNECT predicted: 1 (conf: 0.90), true: 0
# [Row 1572] HRBP predicted: 0 (conf: 0.33), true: 2
# [Row 1583] EXPCO2 predicted: 0 (conf: 0.25), true: 1
# [Row 1584] PAP predicted: 0 (conf: 0.33), true: 1
# [Row 1586] VENTALV predicted: 2 (conf: 0.98), true: 3
# [Row 1587] PAP predicted: 0 (conf: 0.33), true: 1
# [Row 1591] HRSAT predicted: 0 (conf: 0.33), true: 2
# [Row 1594] HRBP predicted: 0 (conf: 0.33), true: 2
# [Row 1604] HRBP predicted: 0 (conf: 0.33), true: 1
# [Row 1608] HRBP predicted: 0 (conf: 0.33), true: 2
# [Row 1625] PAP predicted: 0 (conf: 0.33), true: 1
# [Row 1635] ARTCO2 predicted: 1 (conf: 0.50), true: 2
# [Row 1637] PRESS predicted: 0 (conf: 0.25), true: 3
# [Row 1638] HRSAT predicted: 0 (conf: 0.33), true: 2
# [Row 1641] HRSAT predicted: 0 (conf: 0.33), true: 2
# [Row 1647] BP predicted: 2 (conf: 0.55), true: 1
# [Row 1650] CO predicted: 0 (conf: 0.80), true: 1
# [Row 1652] CVP predicted: 0 (conf: 0.95), true: 1
# [Row 1653] MINVOL predicted: 0 (conf: 0.25), true: 3
# [Row 1653] PRESS predicted: 0 (conf: 0.25), true: 3
# [Row 1656] VENTMACH predicted: 0 (conf: 0.33), true: 2
# [Row 1657] EXPCO2 predicted: 0 (conf: 0.25), true: 1
# [Row 1660] ARTCO2 predicted: 1 (conf: 0.50), true: 2
# [Row 1661] HRSAT predicted: 0 (conf: 0.33), true: 1
# [Row 1662] EXPCO2 predicted: 0 (conf: 0.25), true: 1
# [Row 1664] HREKG predicted: 0 (conf: 0.33), true: 2
# [Row 1665] EXPCO2 predicted: 0 (conf: 0.25), true: 3
# [Row 1666] HREKG predicted: 0 (conf: 0.33), true: 2
# [Row 1667] TPR predicted: 0 (conf: 0.50), true: 1
# [Row 1670] HRBP predicted: 0 (conf: 0.33), true: 2
# [Row 1670] EXPCO2 predicted: 0 (conf: 0.25), true: 1
# [Row 1672] MINVOL predicted: 0 (conf: 0.25), true: 1
# [Row 1674] TPR predicted: 2 (conf: 0.50), true: 1
# [Row 1675] PRESS predicted: 0 (conf: 0.25), true: 3
# [Row 1676] PRESS predicted: 0 (conf: 0.25), true: 3
# [Row 1678] HRBP predicted: 0 (conf: 0.33), true: 2
# [Row 1680] HREKG predicted: 0 (conf: 0.33), true: 2
# [Row 1691] STROKEVOLUME predicted: 2 (conf: 0.51), true: 1
# [Row 1697] PRESS predicted: 0 (conf: 0.25), true: 1
# [Row 1703] BP predicted: 1 (conf: 0.85), true: 0
# [Row 1706] CVP predicted: 2 (conf: 0.70), true: 0
# [Row 1706] EXPCO2 predicted: 0 (conf: 0.25), true: 3
# [Row 1708] HREKG predicted: 0 (conf: 0.33), true: 2
# [Row 1718] PRESS predicted: 0 (conf: 0.25), true: 3
# [Row 1720] PAP predicted: 0 (conf: 0.33), true: 1
# [Row 1724] HREKG predicted: 0 (conf: 0.33), true: 2
# [Row 1726] PRESS predicted: 0 (conf: 0.25), true: 3
# [Row 1733] STROKEVOLUME predicted: 2 (conf: 0.51), true: 1
# [Row 1734] HREKG predicted: 0 (conf: 0.33), true: 2
# [Row 1735] HREKG predicted: 0 (conf: 0.33), true: 2
# [Row 1743] LVEDVOLUME predicted: 2 (conf: 0.62), true: 1
# [Row 1756] PRESS predicted: 0 (conf: 0.25), true: 1
# [Row 1758] EXPCO2 predicted: 0 (conf: 0.25), true: 1
# [Row 1759] PAP predicted: 0 (conf: 0.33), true: 1
# [Row 1764] HREKG predicted: 0 (conf: 0.33), true: 2
# [Row 1765] PAP predicted: 0 (conf: 0.33), true: 2
# [Row 1768] HRSAT predicted: 0 (conf: 0.33), true: 2
# [Row 1771] EXPCO2 predicted: 0 (conf: 0.25), true: 3
# [Row 1779] SAO2 predicted: 0 (conf: 0.33), true: 2
# [Row 1783] HRBP predicted: 0 (conf: 0.33), true: 2
# [Row 1784] PRESS predicted: 0 (conf: 0.25), true: 1
# [Row 1802] PRESS predicted: 0 (conf: 0.25), true: 3
# [Row 1804] SAO2 predicted: 0 (conf: 0.34), true: 2
# [Row 1805] INSUFFANESTH predicted: 1 (conf: 0.90), true: 0
# [Row 1809] HRBP predicted: 0 (conf: 0.33), true: 2
# [Row 1810] HREKG predicted: 0 (conf: 0.33), true: 2
# [Row 1818] PRESS predicted: 0 (conf: 0.25), true: 3
# [Row 1828] HREKG predicted: 0 (conf: 0.33), true: 2
# [Row 1831] PAP predicted: 0 (conf: 0.33), true: 1
# [Row 1841] PAP predicted: 0 (conf: 0.33), true: 1
# [Row 1841] CO predicted: 0 (conf: 0.80), true: 1
# [Row 1842] ARTCO2 predicted: 1 (conf: 0.50), true: 2
# [Row 1844] HRBP predicted: 0 (conf: 0.33), true: 2
# [Row 1850] PRESS predicted: 0 (conf: 0.25), true: 3
# [Row 1853] PRESS predicted: 0 (conf: 0.25), true: 3
# [Row 1855] HREKG predicted: 0 (conf: 0.33), true: 1
# [Row 1863] PRESS predicted: 0 (conf: 0.25), true: 1
# [Row 1867] ARTCO2 predicted: 1 (conf: 0.50), true: 2
# [Row 1879] EXPCO2 predicted: 0 (conf: 0.25), true: 1
# [Row 1881] HRSAT predicted: 0 (conf: 0.33), true: 2
# [Row 1890] HREKG predicted: 0 (conf: 0.33), true: 2
# [Row 1892] HRBP predicted: 0 (conf: 0.33), true: 2
# [Row 1895] PRESS predicted: 0 (conf: 0.25), true: 1
# [Row 1901] PAP predicted: 0 (conf: 0.33), true: 1
# [Row 1907] EXPCO2 predicted: 0 (conf: 0.25), true: 1
# [Row 1908] PAP predicted: 0 (conf: 0.33), true: 1
# [Row 1909] MINVOL predicted: 0 (conf: 0.25), true: 3
# [Row 1925] HRBP predicted: 0 (conf: 0.33), true: 2
# [Row 1927] HREKG predicted: 0 (conf: 0.33), true: 2
# [Row 1928] HREKG predicted: 0 (conf: 0.33), true: 1
# [Row 1936] INSUFFANESTH predicted: 1 (conf: 0.90), true: 0
# [Row 1939] CATECHOL predicted: 0 (conf: 0.91), true: 1
# [Row 1946] HRBP predicted: 0 (conf: 0.33), true: 2
# [Row 1948] HRBP predicted: 0 (conf: 0.33), true: 2
# [Row 1950] HRSAT predicted: 0 (conf: 0.33), true: 2
# [Row 1954] FIO2 predicted: 1 (conf: 0.95), true: 0
# [Row 1958] CVP predicted: 2 (conf: 0.70), true: 1
# [Row 1963] EXPCO2 predicted: 0 (conf: 0.25), true: 1
# [Row 1979] HRSAT predicted: 0 (conf: 0.33), true: 2
# [Row 1995] HRBP predicted: 0 (conf: 0.33), true: 2
# [Row 1998] PRESS predicted: 0 (conf: 0.25), true: 3
#
# Final Accuracy: 0.7671
# Average Confidence: 0.7650
# (0.7671164417791104, 0.7650175380408207)

# %%
data = "andes"
evaluate_network(
    MODELS + f"{data}/{data}_complete.bif",
    DATA + f"{data}/test.csv",
    DATA + f"{data}/test_missing.csv",
    verbose=True
)
# Out:
# Evaluating: 100%|██████████| 2000/2000 [02:56<00:00, 11.32it/s]
# Mismatches (387):
# [Row 3] GOAL_130 predicted: 0 (conf: 0.80), true: 1
# [Row 8] SNode_26 predicted: 0 (conf: 0.50), true: 1
# [Row 16] TRY24 predicted: 0 (conf: 0.50), true: 1
# [Row 19] DEFINE23 predicted: 1 (conf: 0.83), true: 0
# [Row 20] NEWTONS45 predicted: 0 (conf: 0.50), true: 1
# [Row 31] HORIZ53 predicted: 0 (conf: 0.50), true: 1
# [Row 37] RApp4 predicted: 0 (conf: 0.50), true: 1
# [Row 49] WRITE31 predicted: 0 (conf: 0.50), true: 1
# [Row 50] SNode_51 predicted: 1 (conf: 0.83), true: 0
# [Row 51] SNode_25 predicted: 0 (conf: 0.50), true: 1
# [Row 53] APPLY61 predicted: 0 (conf: 0.50), true: 1
# [Row 59] TRY24 predicted: 0 (conf: 0.50), true: 1
# [Row 64] VECTOR73 predicted: 0 (conf: 0.50), true: 1
# [Row 67] RApp3 predicted: 0 (conf: 0.50), true: 1
# [Row 77] SNode_124 predicted: 0 (conf: 0.90), true: 1
# [Row 84] DEFINE23 predicted: 0 (conf: 0.50), true: 1
# [Row 86] SNode_118 predicted: 0 (conf: 0.80), true: 1
# [Row 90] AXIS33 predicted: 1 (conf: 0.80), true: 0
# [Row 90] GOAL72 predicted: 0 (conf: 0.50), true: 1
# [Row 107] SNode_47 predicted: 0 (conf: 0.50), true: 1
# [Row 126] NEWTONS45 predicted: 0 (conf: 0.50), true: 1
# [Row 129] TRY13 predicted: 0 (conf: 0.50), true: 1
# [Row 129] GOAL_99 predicted: 0 (conf: 0.80), true: 1
# [Row 130] IDENTIFY59 predicted: 0 (conf: 0.50), true: 1
# [Row 131] SNode_95 predicted: 0 (conf: 0.80), true: 1
# [Row 137] KINE29 predicted: 0 (conf: 0.50), true: 1
# [Row 139] SNode_100 predicted: 0 (conf: 0.80), true: 1
# [Row 144] CHOOSE62 predicted: 0 (conf: 0.50), true: 1
# [Row 152] GOAL_61 predicted: 1 (conf: 0.83), true: 0
# [Row 155] IDENTIFY39 predicted: 0 (conf: 0.50), true: 1
# [Row 155] HORIZ53 predicted: 0 (conf: 0.50), true: 1
# [Row 160] INCLINE51 predicted: 0 (conf: 0.50), true: 1
# [Row 169] DISPLACEM0 predicted: 0 (conf: 0.50), true: 1
# [Row 175] STRAT_90 predicted: 0 (conf: 0.50), true: 1
# [Row 177] GOAL65 predicted: 0 (conf: 0.50), true: 1
# [Row 183] SUM75 predicted: 0 (conf: 0.50), true: 1
# [Row 186] TRY24 predicted: 0 (conf: 0.50), true: 1
# [Row 203] IDENTIFY55 predicted: 0 (conf: 0.50), true: 1
# [Row 221] FIND49 predicted: 0 (conf: 0.50), true: 1
# [Row 224] TRY13 predicted: 0 (conf: 0.50), true: 1
# [Row 235] SNode_29 predicted: 1 (conf: 0.91), true: 0
# [Row 237] STRAT_90 predicted: 0 (conf: 0.50), true: 1
# [Row 246] SNode_25 predicted: 0 (conf: 0.50), true: 1
# [Row 261] SNode_40 predicted: 0 (conf: 0.90), true: 1
# [Row 270] TRY13 predicted: 0 (conf: 0.50), true: 1
# [Row 272] GOAL_153 predicted: 0 (conf: 0.80), true: 1
# [Row 273] TRY26 predicted: 0 (conf: 0.50), true: 1
# [Row 274] SNode_33 predicted: 0 (conf: 0.50), true: 1
# [Row 276] VALUE3 predicted: 0 (conf: 0.50), true: 1
# [Row 281] GOAL_130 predicted: 1 (conf: 0.56), true: 0
# [Row 284] SNode_25 predicted: 0 (conf: 0.50), true: 1
# [Row 284] TRY26 predicted: 0 (conf: 0.50), true: 1
# [Row 288] KINE29 predicted: 0 (conf: 0.50), true: 1
# [Row 296] GOAL_48 predicted: 0 (conf: 0.50), true: 1
# [Row 299] RESOLVE40 predicted: 0 (conf: 0.50), true: 1
# [Row 303] SNode_97 predicted: 0 (conf: 0.80), true: 1
# [Row 304] SNode_118 predicted: 0 (conf: 0.80), true: 1
# [Row 310] SNode_41 predicted: 0 (conf: 0.50), true: 1
# [Row 312] IDENTIFY9 predicted: 0 (conf: 0.50), true: 1
# [Row 326] TRY14 predicted: 0 (conf: 0.50), true: 1
# [Row 336] SNode_27 predicted: 0 (conf: 0.50), true: 1
# [Row 338] HORIZ53 predicted: 0 (conf: 0.50), true: 1
# [Row 344] GOAL_49 predicted: 1 (conf: 0.83), true: 0
# [Row 354] FIND58 predicted: 0 (conf: 0.70), true: 1
# [Row 354] WRITE64 predicted: 0 (conf: 0.50), true: 1
# [Row 355] GOAL_62 predicted: 0 (conf: 0.50), true: 1
# [Row 355] KINE29 predicted: 0 (conf: 0.50), true: 1
# [Row 361] GOAL_99 predicted: 0 (conf: 0.80), true: 1
# [Row 362] GRAV78 predicted: 0 (conf: 0.50), true: 1
# [Row 366] SNode_27 predicted: 0 (conf: 0.50), true: 1
# [Row 372] SNode_125 predicted: 0 (conf: 0.90), true: 1
# [Row 377] RESOLVE42 predicted: 0 (conf: 0.50), true: 1
# [Row 378] WEIGHT57 predicted: 1 (conf: 0.70), true: 0
# [Row 383] SNode_55 predicted: 0 (conf: 0.50), true: 1
# [Row 386] NEED67 predicted: 0 (conf: 0.50), true: 1
# [Row 402] SNode_47 predicted: 0 (conf: 0.50), true: 1
# [Row 408] SNode_67 predicted: 0 (conf: 0.80), true: 1
# [Row 410] GOAL_121 predicted: 1 (conf: 0.86), true: 0
# [Row 415] GOAL_49 predicted: 0 (conf: 0.50), true: 1
# [Row 420] RApp2 predicted: 0 (conf: 0.50), true: 1
# [Row 423] IDENTIFY59 predicted: 0 (conf: 0.50), true: 1
# [Row 430] SNode_67 predicted: 1 (conf: 0.71), true: 0
# [Row 431] GOAL66 predicted: 0 (conf: 0.60), true: 1
# [Row 434] SNode_47 predicted: 0 (conf: 0.50), true: 1
# [Row 436] RESOLVE42 predicted: 0 (conf: 0.50), true: 1
# [Row 439] SNode_27 predicted: 0 (conf: 0.50), true: 1
# [Row 440] SNode_60 predicted: 0 (conf: 0.50), true: 1
# [Row 443] SNode_64 predicted: 0 (conf: 0.50), true: 1
# [Row 451] WRITE30 predicted: 0 (conf: 0.50), true: 1
# [Row 454] VECTOR27 predicted: 0 (conf: 0.50), true: 1
# [Row 465] RESOLVE37 predicted: 0 (conf: 0.50), true: 1
# [Row 481] TRY26 predicted: 0 (conf: 0.50), true: 1
# [Row 485] SYSTEM18 predicted: 0 (conf: 0.50), true: 1
# [Row 492] DEFINE23 predicted: 0 (conf: 0.50), true: 1
# [Row 494] GOAL_126 predicted: 0 (conf: 0.80), true: 1
# [Row 506] RApp2 predicted: 0 (conf: 0.50), true: 1
# [Row 508] HORIZ53 predicted: 0 (conf: 0.50), true: 1
# [Row 510] SNode_46 predicted: 0 (conf: 0.90), true: 1
# [Row 514] NULL48 predicted: 0 (conf: 0.50), true: 1
# [Row 519] EQUATION28 predicted: 0 (conf: 0.60), true: 1
# [Row 522] GOAL72 predicted: 0 (conf: 0.50), true: 1
# [Row 529] RApp2 predicted: 0 (conf: 0.50), true: 1
# [Row 534] GOAL72 predicted: 0 (conf: 0.50), true: 1
# [Row 536] TRY15 predicted: 0 (conf: 0.50), true: 1
# [Row 538] IDENTIFY39 predicted: 0 (conf: 0.50), true: 1
# [Row 543] GOAL_127 predicted: 0 (conf: 0.80), true: 1
# [Row 549] SNode_152 predicted: 0 (conf: 0.80), true: 1
# [Row 552] APPLY77 predicted: 0 (conf: 0.50), true: 1
# [Row 555] SNode_34 predicted: 0 (conf: 0.50), true: 1
# [Row 561] GOAL_110 predicted: 0 (conf: 0.80), true: 1
# [Row 563] IDENTIFY41 predicted: 0 (conf: 0.50), true: 1
# [Row 566] GOAL_50 predicted: 0 (conf: 0.50), true: 1
# [Row 567] TRY11 predicted: 0 (conf: 0.50), true: 1
# [Row 584] GOAL_62 predicted: 0 (conf: 0.50), true: 1
# [Row 586] APPLY77 predicted: 1 (conf: 0.83), true: 0
# [Row 591] TRY13 predicted: 0 (conf: 0.50), true: 1
# [Row 594] SNode_64 predicted: 0 (conf: 0.50), true: 1
# [Row 601] TRY24 predicted: 0 (conf: 0.50), true: 1
# [Row 604] SNode_60 predicted: 0 (conf: 0.50), true: 1
# [Row 605] GOAL_62 predicted: 1 (conf: 0.96), true: 0
# [Row 609] RESOLVE40 predicted: 0 (conf: 0.50), true: 1
# [Row 614] SNode_117 predicted: 0 (conf: 0.80), true: 1
# [Row 616] IDENTIFY41 predicted: 0 (conf: 0.50), true: 1
# [Row 617] SNode_27 predicted: 0 (conf: 0.50), true: 1
# [Row 622] GOAL_153 predicted: 0 (conf: 0.80), true: 1
# [Row 626] INCLINE51 predicted: 0 (conf: 0.50), true: 1
# [Row 626] APPLY77 predicted: 0 (conf: 0.50), true: 1
# [Row 633] RESOLVE37 predicted: 0 (conf: 0.50), true: 1
# [Row 635] WRITE30 predicted: 0 (conf: 0.50), true: 1
# [Row 635] IDENTIFY59 predicted: 0 (conf: 0.50), true: 1
# [Row 640] GOAL65 predicted: 1 (conf: 0.75), true: 0
# [Row 644] KINEMATI17 predicted: 0 (conf: 0.50), true: 1
# [Row 645] KINEMATI17 predicted: 0 (conf: 0.50), true: 1
# [Row 648] DEFINE23 predicted: 0 (conf: 0.50), true: 1
# [Row 651] SNode_54 predicted: 0 (conf: 0.50), true: 1
# [Row 652] GOAL_72 predicted: 0 (conf: 0.50), true: 1
# [Row 658] SNode_92 predicted: 0 (conf: 0.50), true: 1
# [Row 659] KINEMATI17 predicted: 0 (conf: 0.50), true: 1
# [Row 661] FIND58 predicted: 0 (conf: 0.70), true: 1
# [Row 662] SUM75 predicted: 0 (conf: 0.50), true: 1
# [Row 667] SYSTEM46 predicted: 0 (conf: 0.50), true: 1
# [Row 670] SNode_65 predicted: 0 (conf: 0.50), true: 1
# [Row 679] SNode_25 predicted: 0 (conf: 0.50), true: 1
# [Row 682] KINEMATI17 predicted: 0 (conf: 0.50), true: 1
# [Row 682] SNode_60 predicted: 0 (conf: 0.50), true: 1
# [Row 687] GOAL_53 predicted: 1 (conf: 0.83), true: 0
# [Row 691] SNode_117 predicted: 0 (conf: 0.80), true: 1
# [Row 693] RApp2 predicted: 0 (conf: 0.50), true: 1
# [Row 707] EQUAL71 predicted: 1 (conf: 0.60), true: 0
# [Row 734] SNode_92 predicted: 0 (conf: 0.50), true: 1
# [Row 736] SNode_71 predicted: 0 (conf: 0.50), true: 1
# [Row 737] SNode_92 predicted: 0 (conf: 0.50), true: 1
# [Row 738] SNode_21 predicted: 0 (conf: 0.50), true: 1
# [Row 738] NEWTONS45 predicted: 0 (conf: 0.50), true: 1
# [Row 741] SYSTEM46 predicted: 0 (conf: 0.50), true: 1
# [Row 742] SNode_54 predicted: 0 (conf: 0.50), true: 1
# [Row 750] TRY26 predicted: 0 (conf: 0.50), true: 1
# [Row 753] GOAL_129 predicted: 0 (conf: 0.80), true: 1
# [Row 757] RApp2 predicted: 0 (conf: 0.50), true: 1
# [Row 757] NORMAL50 predicted: 0 (conf: 0.50), true: 1
# [Row 759] SNode_92 predicted: 0 (conf: 0.50), true: 1
# [Row 761] NEWTONS74 predicted: 0 (conf: 0.50), true: 1
# [Row 763] DEFINE23 predicted: 0 (conf: 0.50), true: 1
# [Row 768] VECTOR44 predicted: 0 (conf: 0.50), true: 1
# [Row 776] NEWTONS45 predicted: 0 (conf: 0.50), true: 1
# [Row 777] SNode_128 predicted: 0 (conf: 0.80), true: 1
# [Row 798] GOAL_63 predicted: 0 (conf: 0.50), true: 1
# [Row 800] VECTOR44 predicted: 0 (conf: 0.50), true: 1
# [Row 805] SNode_100 predicted: 0 (conf: 0.80), true: 1
# [Row 807] HORIZ53 predicted: 0 (conf: 0.50), true: 1
# [Row 815] RESOLVE42 predicted: 0 (conf: 0.50), true: 1
# [Row 819] GOAL_69 predicted: 1 (conf: 0.83), true: 0
# [Row 820] TRY24 predicted: 0 (conf: 0.50), true: 1
# [Row 826] SNode_156 predicted: 0 (conf: 0.80), true: 1
# [Row 827] KINE29 predicted: 0 (conf: 0.50), true: 1
# [Row 829] TRY13 predicted: 0 (conf: 0.50), true: 1
# [Row 831] SNode_59 predicted: 0 (conf: 0.50), true: 1
# [Row 837] SNode_64 predicted: 0 (conf: 0.50), true: 1
# [Row 838] APPLY32 predicted: 0 (conf: 0.50), true: 1
# [Row 840] IDENTIFY9 predicted: 0 (conf: 0.50), true: 1
# [Row 858] BUGGY54 predicted: 0 (conf: 0.50), true: 1
# [Row 860] RApp2 predicted: 0 (conf: 0.50), true: 1
# [Row 887] INCLINE51 predicted: 0 (conf: 0.50), true: 1
# [Row 894] SNode_94 predicted: 0 (conf: 0.64), true: 1
# [Row 896] GOAL_48 predicted: 0 (conf: 0.50), true: 1
# [Row 898] SNode_20 predicted: 0 (conf: 0.50), true: 1
# [Row 899] IDENTIFY22 predicted: 0 (conf: 0.50), true: 1
# [Row 908] VECTOR27 predicted: 0 (conf: 0.50), true: 1
# [Row 915] KINEMATI17 predicted: 0 (conf: 0.50), true: 1
# [Row 917] SYSTEM18 predicted: 0 (conf: 0.50), true: 1
# [Row 919] SNode_54 predicted: 0 (conf: 0.50), true: 1
# [Row 928] RApp2 predicted: 0 (conf: 0.50), true: 1
# [Row 934] SNode_34 predicted: 0 (conf: 0.50), true: 1
# [Row 936] SNode_92 predicted: 0 (conf: 0.50), true: 1
# [Row 947] KINE29 predicted: 0 (conf: 0.50), true: 1
# [Row 948] GOAL72 predicted: 0 (conf: 0.50), true: 1
# [Row 949] GOAL_83 predicted: 0 (conf: 0.80), true: 1
# [Row 949] SNode_38 predicted: 0 (conf: 0.80), true: 1
# [Row 950] WRITE63 predicted: 0 (conf: 0.50), true: 1
# [Row 951] GOAL_81 predicted: 1 (conf: 0.56), true: 0
# [Row 961] SYSTEM18 predicted: 0 (conf: 0.50), true: 1
# [Row 961] SNode_34 predicted: 0 (conf: 0.50), true: 1
# [Row 966] RESOLVE42 predicted: 0 (conf: 0.50), true: 1
# [Row 966] SNode_71 predicted: 0 (conf: 0.50), true: 1
# [Row 976] SNode_27 predicted: 0 (conf: 0.50), true: 1
# [Row 984] SNode_97 predicted: 0 (conf: 0.80), true: 1
# [Row 986] GOAL_62 predicted: 0 (conf: 0.50), true: 1
# [Row 999] GOAL_50 predicted: 0 (conf: 0.50), true: 1
# [Row 1006] GRAV2 predicted: 0 (conf: 0.50), true: 1
# [Row 1007] WRITE63 predicted: 0 (conf: 0.50), true: 1
# [Row 1029] CHOOSE62 predicted: 0 (conf: 0.50), true: 1
# [Row 1031] INCLINE51 predicted: 0 (conf: 0.50), true: 1
# [Row 1061] SNode_119 predicted: 0 (conf: 0.90), true: 1
# [Row 1063] NULL48 predicted: 0 (conf: 0.50), true: 1
# [Row 1065] IDENTIFY22 predicted: 0 (conf: 0.50), true: 1
# [Row 1073] GOAL_81 predicted: 1 (conf: 0.56), true: 0
# [Row 1078] FIND49 predicted: 0 (conf: 0.50), true: 1
# [Row 1086] MAXIMIZE34 predicted: 0 (conf: 0.50), true: 1
# [Row 1087] GOAL65 predicted: 0 (conf: 0.50), true: 1
# [Row 1095] KINEMATI17 predicted: 0 (conf: 0.50), true: 1
# [Row 1096] SNode_132 predicted: 0 (conf: 0.90), true: 1
# [Row 1099] SNode_41 predicted: 0 (conf: 0.50), true: 1
# [Row 1099] DEFINE23 predicted: 0 (conf: 0.50), true: 1
# [Row 1103] GOAL_84 predicted: 1 (conf: 0.71), true: 0
# [Row 1103] GRAV78 predicted: 0 (conf: 0.50), true: 1
# [Row 1106] VECTOR73 predicted: 0 (conf: 0.50), true: 1
# [Row 1111] RApp6 predicted: 0 (conf: 0.50), true: 1
# [Row 1117] RESOLVE42 predicted: 0 (conf: 0.50), true: 1
# [Row 1125] SNode_67 predicted: 0 (conf: 0.80), true: 1
# [Row 1125] IDENTIFY55 predicted: 0 (conf: 0.50), true: 1
# [Row 1129] RApp2 predicted: 0 (conf: 0.50), true: 1
# [Row 1131] CHOOSE35 predicted: 0 (conf: 0.50), true: 1
# [Row 1134] GOAL65 predicted: 0 (conf: 0.50), true: 1
# [Row 1139] SNode_47 predicted: 0 (conf: 0.50), true: 1
# [Row 1139] EQUAL71 predicted: 1 (conf: 0.60), true: 0
# [Row 1141] GOAL68 predicted: 0 (conf: 0.50), true: 1
# [Row 1150] CHOOSE35 predicted: 0 (conf: 0.50), true: 1
# [Row 1152] SNode_59 predicted: 0 (conf: 0.50), true: 1
# [Row 1155] IDENTIFY39 predicted: 0 (conf: 0.50), true: 1
# [Row 1158] SNode_34 predicted: 0 (conf: 0.50), true: 1
# [Row 1159] CHOOSE19 predicted: 0 (conf: 0.50), true: 1
# [Row 1168] GOAL_99 predicted: 0 (conf: 0.80), true: 1
# [Row 1169] NEED67 predicted: 0 (conf: 0.50), true: 1
# [Row 1172] SNode_25 predicted: 0 (conf: 0.50), true: 1
# [Row 1176] SNode_29 predicted: 1 (conf: 0.91), true: 0
# [Row 1178] GOAL68 predicted: 0 (conf: 0.50), true: 1
# [Row 1183] GOAL_48 predicted: 0 (conf: 0.50), true: 1
# [Row 1185] EQUATION28 predicted: 0 (conf: 0.60), true: 1
# [Row 1186] IDENTIFY10 predicted: 0 (conf: 0.50), true: 1
# [Row 1189] VECTOR69 predicted: 0 (conf: 0.70), true: 1
# [Row 1190] CHOOSE62 predicted: 0 (conf: 0.50), true: 1
# [Row 1193] NORMAL50 predicted: 0 (conf: 0.67), true: 1
# [Row 1210] GOAL65 predicted: 0 (conf: 0.50), true: 1
# [Row 1216] TRY26 predicted: 0 (conf: 0.50), true: 1
# [Row 1217] GOAL_121 predicted: 0 (conf: 0.80), true: 1
# [Row 1234] SNode_115 predicted: 0 (conf: 0.80), true: 1
# [Row 1236] STRAT_90 predicted: 0 (conf: 0.50), true: 1
# [Row 1246] NEWTONS45 predicted: 0 (conf: 0.50), true: 1
# [Row 1247] SNode_27 predicted: 0 (conf: 0.50), true: 1
# [Row 1257] SNode_135 predicted: 0 (conf: 0.90), true: 1
# [Row 1266] FIND49 predicted: 0 (conf: 0.50), true: 1
# [Row 1276] GOAL_48 predicted: 0 (conf: 0.50), true: 1
# [Row 1276] VECTOR27 predicted: 0 (conf: 0.50), true: 1
# [Row 1277] INCLINE51 predicted: 0 (conf: 0.50), true: 1
# [Row 1288] SNode_29 predicted: 0 (conf: 0.50), true: 1
# [Row 1288] AXIS33 predicted: 1 (conf: 0.95), true: 0
# [Row 1289] FIND49 predicted: 0 (conf: 0.50), true: 1
# [Row 1297] GOAL_113 predicted: 0 (conf: 0.80), true: 1
# [Row 1309] TRY26 predicted: 0 (conf: 0.50), true: 1
# [Row 1312] INCLINE51 predicted: 0 (conf: 0.50), true: 1
# [Row 1321] TRY76 predicted: 0 (conf: 0.50), true: 1
# [Row 1327] CHOOSE47 predicted: 0 (conf: 0.50), true: 1
# [Row 1331] SNode_73 predicted: 0 (conf: 0.50), true: 1
# [Row 1332] WEIGHT56 predicted: 1 (conf: 0.70), true: 0
# [Row 1335] KINEMATI17 predicted: 1 (conf: 0.83), true: 0
# [Row 1340] SNode_136 predicted: 0 (conf: 0.90), true: 1
# [Row 1348] TRY26 predicted: 0 (conf: 0.50), true: 1
# [Row 1364] RESOLVE40 predicted: 0 (conf: 0.50), true: 1
# [Row 1365] RESOLVE42 predicted: 0 (conf: 0.50), true: 1
# [Row 1371] SNode_60 predicted: 0 (conf: 0.50), true: 1
# [Row 1377] SNode_17 predicted: 1 (conf: 0.98), true: 0
# [Row 1412] GOAL_79 predicted: 0 (conf: 0.80), true: 1
# [Row 1413] RESOLVE37 predicted: 0 (conf: 0.50), true: 1
# [Row 1430] SNode_88 predicted: 0 (conf: 0.90), true: 1
# [Row 1431] SNode_131 predicted: 0 (conf: 0.80), true: 1
# [Row 1434] SNode_97 predicted: 0 (conf: 0.80), true: 1
# [Row 1435] SNode_91 predicted: 1 (conf: 0.56), true: 0
# [Row 1452] NULL48 predicted: 0 (conf: 0.50), true: 1
# [Row 1453] SNode_34 predicted: 0 (conf: 0.50), true: 1
# [Row 1455] FIND49 predicted: 0 (conf: 0.50), true: 1
# [Row 1464] MAXIMIZE34 predicted: 1 (conf: 0.83), true: 0
# [Row 1489] VECTOR44 predicted: 0 (conf: 0.50), true: 1
# [Row 1489] WRITE64 predicted: 0 (conf: 0.50), true: 1
# [Row 1501] IDENTIFY55 predicted: 1 (conf: 0.83), true: 0
# [Row 1506] TRY14 predicted: 0 (conf: 0.50), true: 1
# [Row 1506] APPLY77 predicted: 0 (conf: 0.50), true: 1
# [Row 1512] NULL48 predicted: 0 (conf: 0.50), true: 1
# [Row 1523] SNode_5 predicted: 1 (conf: 0.98), true: 0
# [Row 1530] APPLY32 predicted: 0 (conf: 0.50), true: 1
# [Row 1535] WRITE63 predicted: 0 (conf: 0.50), true: 1
# [Row 1545] SNode_112 predicted: 0 (conf: 0.80), true: 1
# [Row 1545] SUM75 predicted: 0 (conf: 0.50), true: 1
# [Row 1550] GOAL_107 predicted: 0 (conf: 0.80), true: 1
# [Row 1553] RApp4 predicted: 0 (conf: 0.50), true: 1
# [Row 1553] SNode_100 predicted: 0 (conf: 0.80), true: 1
# [Row 1554] SNode_40 predicted: 0 (conf: 0.90), true: 1
# [Row 1556] TRY13 predicted: 0 (conf: 0.50), true: 1
# [Row 1573] SNode_47 predicted: 0 (conf: 0.50), true: 1
# [Row 1576] IDENTIFY59 predicted: 0 (conf: 0.50), true: 1
# [Row 1581] SNode_75 predicted: 1 (conf: 0.83), true: 0
# [Row 1587] SNode_55 predicted: 0 (conf: 0.50), true: 1
# [Row 1594] SNode_25 predicted: 0 (conf: 0.50), true: 1
# [Row 1599] GOAL_72 predicted: 0 (conf: 0.50), true: 1
# [Row 1600] GOAL_48 predicted: 1 (conf: 0.83), true: 0
# [Row 1601] IDENTIFY59 predicted: 0 (conf: 0.50), true: 1
# [Row 1605] APPLY32 predicted: 0 (conf: 0.50), true: 1
# [Row 1619] GOAL_48 predicted: 0 (conf: 0.50), true: 1
# [Row 1619] IDENTIFY39 predicted: 0 (conf: 0.50), true: 1
# [Row 1621] RApp2 predicted: 0 (conf: 0.50), true: 1
# [Row 1624] TRY13 predicted: 0 (conf: 0.50), true: 1
# [Row 1628] RESOLVE38 predicted: 0 (conf: 0.50), true: 1
# [Row 1631] SNode_64 predicted: 0 (conf: 0.50), true: 1
# [Row 1640] NEWTONS74 predicted: 0 (conf: 0.50), true: 1
# [Row 1651] INCLINE51 predicted: 0 (conf: 0.50), true: 1
# [Row 1661] SNode_59 predicted: 1 (conf: 0.83), true: 0
# [Row 1663] WEIGHT56 predicted: 1 (conf: 0.70), true: 0
# [Row 1670] BUGGY54 predicted: 1 (conf: 0.83), true: 0
# [Row 1674] TRY26 predicted: 0 (conf: 0.50), true: 1
# [Row 1677] SNode_91 predicted: 0 (conf: 0.80), true: 1
# [Row 1678] EQUAL71 predicted: 1 (conf: 0.60), true: 0
# [Row 1683] WRITE31 predicted: 0 (conf: 0.50), true: 1
# [Row 1689] IDENTIFY9 predicted: 0 (conf: 0.50), true: 1
# [Row 1699] NEED1 predicted: 1 (conf: 0.83), true: 0
# [Row 1700] RESOLVE42 predicted: 0 (conf: 0.50), true: 1
# [Row 1703] TRY15 predicted: 0 (conf: 0.50), true: 1
# [Row 1707] WRITE31 predicted: 0 (conf: 0.50), true: 1
# [Row 1710] SNode_93 predicted: 0 (conf: 0.80), true: 1
# [Row 1713] WEIGHT57 predicted: 1 (conf: 0.70), true: 0
# [Row 1731] EQUAL71 predicted: 1 (conf: 0.60), true: 0
# [Row 1734] SYSTEM46 predicted: 0 (conf: 0.50), true: 1
# [Row 1734] APPLY77 predicted: 0 (conf: 0.50), true: 1
# [Row 1743] SNode_43 predicted: 1 (conf: 0.56), true: 0
# [Row 1757] WRITE63 predicted: 0 (conf: 0.50), true: 1
# [Row 1759] KINE29 predicted: 0 (conf: 0.50), true: 1
# [Row 1761] SYSTEM46 predicted: 0 (conf: 0.50), true: 1
# [Row 1764] SNode_33 predicted: 0 (conf: 0.50), true: 1
# [Row 1767] SNode_120 predicted: 0 (conf: 0.90), true: 1
# [Row 1774] NEWTONS74 predicted: 0 (conf: 0.50), true: 1
# [Row 1775] SNode_27 predicted: 0 (conf: 0.50), true: 1
# [Row 1789] SNode_20 predicted: 0 (conf: 0.50), true: 1
# [Row 1794] WEIGHT56 predicted: 1 (conf: 0.70), true: 0
# [Row 1801] CHOOSE35 predicted: 0 (conf: 0.50), true: 1
# [Row 1814] SNode_74 predicted: 0 (conf: 0.90), true: 1
# [Row 1815] SNode_123 predicted: 0 (conf: 0.90), true: 1
# [Row 1826] SNode_119 predicted: 0 (conf: 0.90), true: 1
# [Row 1837] GOAL_127 predicted: 0 (conf: 0.80), true: 1
# [Row 1843] CHOOSE35 predicted: 0 (conf: 0.50), true: 1
# [Row 1844] HORIZ53 predicted: 0 (conf: 0.50), true: 1
# [Row 1845] RESOLVE37 predicted: 0 (conf: 0.50), true: 1
# [Row 1845] GOAL_72 predicted: 0 (conf: 0.50), true: 1
# [Row 1849] CHOOSE19 predicted: 0 (conf: 0.50), true: 1
# [Row 1852] SNode_25 predicted: 0 (conf: 0.50), true: 1
# [Row 1853] GOAL_110 predicted: 0 (conf: 0.80), true: 1
# [Row 1859] GOAL_104 predicted: 0 (conf: 0.80), true: 1
# [Row 1868] COMPO16 predicted: 1 (conf: 0.83), true: 0
# [Row 1876] GOAL_50 predicted: 0 (conf: 0.50), true: 1
# [Row 1877] SNode_54 predicted: 0 (conf: 0.50), true: 1
# [Row 1890] RESOLVE40 predicted: 0 (conf: 0.50), true: 1
# [Row 1905] SNode_26 predicted: 0 (conf: 0.50), true: 1
# [Row 1907] FIND49 predicted: 0 (conf: 0.50), true: 1
# [Row 1908] WEIGHT57 predicted: 1 (conf: 0.70), true: 0
# [Row 1913] SNode_25 predicted: 0 (conf: 0.50), true: 1
# [Row 1917] TRY26 predicted: 0 (conf: 0.50), true: 1
# [Row 1917] GRAV78 predicted: 0 (conf: 0.50), true: 1
# [Row 1923] RESOLVE40 predicted: 0 (conf: 0.50), true: 1
# [Row 1929] IDENTIFY41 predicted: 0 (conf: 0.50), true: 1
# [Row 1935] SYSTEM46 predicted: 0 (conf: 0.50), true: 1
# [Row 1944] SNode_44 predicted: 0 (conf: 0.80), true: 1
# [Row 1950] NEED1 predicted: 0 (conf: 0.50), true: 1
# [Row 1954] IDENTIFY9 predicted: 0 (conf: 0.50), true: 1
# [Row 1970] WRITE31 predicted: 0 (conf: 0.50), true: 1
# [Row 1972] GOAL_57 predicted: 0 (conf: 0.50), true: 1
# [Row 1980] SNode_134 predicted: 0 (conf: 0.90), true: 1
# [Row 1986] TRY13 predicted: 0 (conf: 0.50), true: 1
# [Row 1986] SNode_34 predicted: 0 (conf: 0.50), true: 1
# [Row 1992] SNode_33 predicted: 0 (conf: 0.50), true: 1
# [Row 1997] IDENTIFY39 predicted: 0 (conf: 0.50), true: 1
#
# Final Accuracy: 0.8003
# Average Confidence: 0.7826
# (0.8003095975232198, 0.7825911829030913)

# %%
data = "asia"
evaluate_network(
    MODELS + f"{data}/{data}_complete.bif",
    DATA + f"{data}/test.csv",
    DATA + f"{data}/test_missing.csv",
    verbose=True
)
# Out:
# Evaluating: 100%|██████████| 2000/2000 [00:00<00:00, 3661.52it/s]
# Mismatches (212):
# [Row 3] smoke predicted: 1 (conf: 0.66), true: 0
# [Row 4] bronc predicted: 1 (conf: 0.80), true: 0
# [Row 14] dysp predicted: 0 (conf: 0.80), true: 1
# [Row 16] bronc predicted: 0 (conf: 0.89), true: 1
# [Row 18] xray predicted: 1 (conf: 0.95), true: 0
# [Row 21] smoke predicted: 1 (conf: 0.66), true: 0
# [Row 22] smoke predicted: 1 (conf: 0.66), true: 0
# [Row 26] smoke predicted: 1 (conf: 0.66), true: 0
# [Row 41] dysp predicted: 1 (conf: 0.55), true: 0
# [Row 43] smoke predicted: 1 (conf: 0.66), true: 0
# [Row 50] smoke predicted: 0 (conf: 0.65), true: 1
# [Row 51] smoke predicted: 0 (conf: 0.65), true: 1
# [Row 58] dysp predicted: 0 (conf: 0.80), true: 1
# [Row 59] dysp predicted: 1 (conf: 0.90), true: 0
# [Row 70] dysp predicted: 1 (conf: 0.55), true: 0
# [Row 90] bronc predicted: 0 (conf: 0.56), true: 1
# [Row 99] bronc predicted: 0 (conf: 0.89), true: 1
# [Row 117] dysp predicted: 1 (conf: 0.90), true: 0
# [Row 123] smoke predicted: 1 (conf: 0.61), true: 0
# [Row 136] dysp predicted: 0 (conf: 0.70), true: 1
# [Row 147] dysp predicted: 0 (conf: 0.80), true: 1
# [Row 177] bronc predicted: 1 (conf: 0.82), true: 0
# [Row 180] dysp predicted: 1 (conf: 0.55), true: 0
# [Row 185] dysp predicted: 0 (conf: 0.80), true: 1
# [Row 192] smoke predicted: 1 (conf: 0.66), true: 0
# [Row 198] smoke predicted: 0 (conf: 0.65), true: 1
# [Row 200] smoke predicted: 1 (conf: 0.66), true: 0
# [Row 213] tub predicted: 0 (conf: 0.50), true: 1
# [Row 225] bronc predicted: 0 (conf: 0.68), true: 1
# [Row 246] dysp predicted: 1 (conf: 0.55), true: 0
# [Row 252] dysp predicted: 1 (conf: 0.55), true: 0
# [Row 257] dysp predicted: 0 (conf: 0.80), true: 1
# [Row 270] bronc predicted: 0 (conf: 0.50), true: 1
# [Row 275] smoke predicted: 0 (conf: 0.65), true: 1
# [Row 294] smoke predicted: 0 (conf: 0.85), true: 1
# [Row 301] smoke predicted: 0 (conf: 0.65), true: 1
# [Row 304] dysp predicted: 0 (conf: 0.80), true: 1
# [Row 321] bronc predicted: 0 (conf: 0.56), true: 1
# [Row 324] dysp predicted: 1 (conf: 0.90), true: 0
# [Row 351] dysp predicted: 1 (conf: 0.55), true: 0
# [Row 356] bronc predicted: 0 (conf: 0.56), true: 1
# [Row 379] dysp predicted: 0 (conf: 0.70), true: 1
# [Row 387] smoke predicted: 0 (conf: 0.65), true: 1
# [Row 389] tub predicted: 1 (conf: 0.82), true: 0
# [Row 389] either predicted: 1 (conf: 0.82), true: 0
# [Row 393] smoke predicted: 0 (conf: 0.65), true: 1
# [Row 395] smoke predicted: 0 (conf: 0.65), true: 1
# [Row 407] smoke predicted: 0 (conf: 0.92), true: 1
# [Row 407] bronc predicted: 0 (conf: 0.56), true: 1
# [Row 439] smoke predicted: 1 (conf: 0.61), true: 0
# [Row 441] smoke predicted: 1 (conf: 0.66), true: 0
# [Row 460] smoke predicted: 0 (conf: 0.65), true: 1
# [Row 462] smoke predicted: 1 (conf: 0.66), true: 0
# [Row 466] smoke predicted: 1 (conf: 0.66), true: 0
# [Row 471] xray predicted: 1 (conf: 0.95), true: 0
# [Row 488] bronc predicted: 0 (conf: 0.50), true: 1
# [Row 503] smoke predicted: 0 (conf: 0.60), true: 1
# [Row 516] bronc predicted: 1 (conf: 0.80), true: 0
# [Row 544] lung predicted: 0 (conf: 0.50), true: 1
# [Row 544] dysp predicted: 0 (conf: 0.70), true: 1
# [Row 558] bronc predicted: 1 (conf: 0.82), true: 0
# [Row 566] smoke predicted: 1 (conf: 0.66), true: 0
# [Row 573] smoke predicted: 0 (conf: 0.65), true: 1
# [Row 576] dysp predicted: 0 (conf: 0.80), true: 1
# [Row 581] smoke predicted: 1 (conf: 0.66), true: 0
# [Row 621] smoke predicted: 1 (conf: 0.66), true: 0
# [Row 627] bronc predicted: 1 (conf: 0.82), true: 0
# [Row 634] smoke predicted: 1 (conf: 0.66), true: 0
# [Row 638] smoke predicted: 0 (conf: 0.65), true: 1
# [Row 640] bronc predicted: 0 (conf: 0.89), true: 1
# [Row 643] bronc predicted: 0 (conf: 0.89), true: 1
# [Row 659] bronc predicted: 1 (conf: 0.82), true: 0
# [Row 664] bronc predicted: 1 (conf: 0.82), true: 0
# [Row 665] bronc predicted: 0 (conf: 0.89), true: 1
# [Row 684] dysp predicted: 0 (conf: 0.80), true: 1
# [Row 701] smoke predicted: 1 (conf: 0.66), true: 0
# [Row 703] bronc predicted: 1 (conf: 0.82), true: 0
# [Row 704] smoke predicted: 1 (conf: 0.66), true: 0
# [Row 705] smoke predicted: 1 (conf: 0.61), true: 0
# [Row 713] smoke predicted: 1 (conf: 0.66), true: 0
# [Row 725] smoke predicted: 1 (conf: 0.66), true: 0
# [Row 755] smoke predicted: 0 (conf: 0.85), true: 1
# [Row 763] smoke predicted: 1 (conf: 0.66), true: 0
# [Row 791] bronc predicted: 0 (conf: 0.89), true: 1
# [Row 795] smoke predicted: 0 (conf: 0.60), true: 1
# [Row 807] lung predicted: 0 (conf: 0.91), true: 1
# [Row 807] either predicted: 0 (conf: 0.91), true: 1
# [Row 813] smoke predicted: 1 (conf: 0.66), true: 0
# [Row 816] smoke predicted: 0 (conf: 0.65), true: 1
# [Row 817] smoke predicted: 1 (conf: 0.66), true: 0
# [Row 819] smoke predicted: 1 (conf: 0.61), true: 0
# [Row 824] smoke predicted: 0 (conf: 0.65), true: 1
# [Row 825] smoke predicted: 1 (conf: 0.66), true: 0
# [Row 828] dysp predicted: 1 (conf: 0.55), true: 0
# [Row 831] dysp predicted: 0 (conf: 0.70), true: 1
# [Row 833] bronc predicted: 0 (conf: 0.89), true: 1
# [Row 839] smoke predicted: 0 (conf: 0.65), true: 1
# [Row 840] smoke predicted: 1 (conf: 0.66), true: 0
# [Row 846] bronc predicted: 1 (conf: 0.82), true: 0
# [Row 850] smoke predicted: 1 (conf: 0.66), true: 0
# [Row 853] xray predicted: 1 (conf: 0.95), true: 0
# [Row 853] dysp predicted: 1 (conf: 0.90), true: 0
# [Row 855] smoke predicted: 1 (conf: 0.61), true: 0
# [Row 855] bronc predicted: 1 (conf: 0.82), true: 0
# [Row 865] dysp predicted: 1 (conf: 0.90), true: 0
# [Row 878] xray predicted: 1 (conf: 0.95), true: 0
# [Row 885] smoke predicted: 1 (conf: 0.66), true: 0
# [Row 908] smoke predicted: 0 (conf: 0.65), true: 1
# [Row 916] dysp predicted: 1 (conf: 0.90), true: 0
# [Row 925] smoke predicted: 1 (conf: 0.61), true: 0
# [Row 938] bronc predicted: 0 (conf: 0.50), true: 1
# [Row 948] bronc predicted: 0 (conf: 0.89), true: 1
# [Row 973] bronc predicted: 0 (conf: 0.68), true: 1
# [Row 978] bronc predicted: 1 (conf: 0.82), true: 0
# [Row 1004] smoke predicted: 1 (conf: 0.66), true: 0
# [Row 1011] smoke predicted: 1 (conf: 0.66), true: 0
# [Row 1039] bronc predicted: 1 (conf: 0.82), true: 0
# [Row 1044] smoke predicted: 0 (conf: 0.65), true: 1
# [Row 1051] dysp predicted: 0 (conf: 0.80), true: 1
# [Row 1067] smoke predicted: 1 (conf: 0.66), true: 0
# [Row 1079] dysp predicted: 0 (conf: 0.80), true: 1
# [Row 1105] lung predicted: 0 (conf: 0.50), true: 1
# [Row 1131] dysp predicted: 0 (conf: 0.80), true: 1
# [Row 1133] smoke predicted: 0 (conf: 0.65), true: 1
# [Row 1135] smoke predicted: 0 (conf: 0.65), true: 1
# [Row 1138] dysp predicted: 0 (conf: 0.80), true: 1
# [Row 1140] bronc predicted: 0 (conf: 0.50), true: 1
# [Row 1142] lung predicted: 0 (conf: 0.50), true: 1
# [Row 1144] smoke predicted: 1 (conf: 0.66), true: 0
# [Row 1160] bronc predicted: 0 (conf: 0.50), true: 1
# [Row 1177] bronc predicted: 1 (conf: 0.82), true: 0
# [Row 1183] smoke predicted: 0 (conf: 0.65), true: 1
# [Row 1188] smoke predicted: 0 (conf: 0.65), true: 1
# [Row 1191] smoke predicted: 1 (conf: 0.66), true: 0
# [Row 1199] bronc predicted: 0 (conf: 0.89), true: 1
# [Row 1204] bronc predicted: 1 (conf: 0.82), true: 0
# [Row 1218] dysp predicted: 1 (conf: 0.55), true: 0
# [Row 1224] smoke predicted: 1 (conf: 0.66), true: 0
# [Row 1234] smoke predicted: 0 (conf: 0.60), true: 1
# [Row 1234] bronc predicted: 0 (conf: 0.89), true: 1
# [Row 1235] smoke predicted: 1 (conf: 0.66), true: 0
# [Row 1269] smoke predicted: 1 (conf: 0.66), true: 0
# [Row 1284] smoke predicted: 1 (conf: 0.66), true: 0
# [Row 1291] bronc predicted: 0 (conf: 0.50), true: 1
# [Row 1297] smoke predicted: 1 (conf: 0.66), true: 0
# [Row 1305] smoke predicted: 0 (conf: 0.65), true: 1
# [Row 1332] bronc predicted: 1 (conf: 0.82), true: 0
# [Row 1340] bronc predicted: 0 (conf: 0.89), true: 1
# [Row 1349] bronc predicted: 0 (conf: 0.50), true: 1
# [Row 1353] dysp predicted: 0 (conf: 0.80), true: 1
# [Row 1362] smoke predicted: 1 (conf: 0.61), true: 0
# [Row 1364] dysp predicted: 0 (conf: 0.80), true: 1
# [Row 1385] bronc predicted: 0 (conf: 0.89), true: 1
# [Row 1388] bronc predicted: 1 (conf: 0.82), true: 0
# [Row 1401] dysp predicted: 1 (conf: 0.90), true: 0
# [Row 1434] dysp predicted: 0 (conf: 0.80), true: 1
# [Row 1463] dysp predicted: 1 (conf: 0.90), true: 0
# [Row 1479] smoke predicted: 1 (conf: 0.66), true: 0
# [Row 1481] smoke predicted: 0 (conf: 0.65), true: 1
# [Row 1487] smoke predicted: 1 (conf: 0.66), true: 0
# [Row 1490] smoke predicted: 1 (conf: 0.66), true: 0
# [Row 1505] dysp predicted: 0 (conf: 0.80), true: 1
# [Row 1528] dysp predicted: 1 (conf: 0.55), true: 0
# [Row 1546] smoke predicted: 0 (conf: 0.60), true: 1
# [Row 1546] bronc predicted: 0 (conf: 0.89), true: 1
# [Row 1550] smoke predicted: 1 (conf: 0.66), true: 0
# [Row 1554] xray predicted: 1 (conf: 0.95), true: 0
# [Row 1560] bronc predicted: 1 (conf: 0.82), true: 0
# [Row 1572] bronc predicted: 0 (conf: 0.50), true: 1
# [Row 1572] dysp predicted: 1 (conf: 0.55), true: 0
# [Row 1596] bronc predicted: 0 (conf: 0.89), true: 1
# [Row 1599] smoke predicted: 1 (conf: 0.66), true: 0
# [Row 1612] smoke predicted: 1 (conf: 0.66), true: 0
# [Row 1640] bronc predicted: 1 (conf: 0.82), true: 0
# [Row 1648] smoke predicted: 0 (conf: 0.65), true: 1
# [Row 1651] bronc predicted: 1 (conf: 0.82), true: 0
# [Row 1672] bronc predicted: 0 (conf: 0.50), true: 1
# [Row 1674] smoke predicted: 0 (conf: 0.65), true: 1
# [Row 1678] xray predicted: 1 (conf: 0.95), true: 0
# [Row 1682] dysp predicted: 1 (conf: 0.90), true: 0
# [Row 1686] bronc predicted: 0 (conf: 0.89), true: 1
# [Row 1694] smoke predicted: 1 (conf: 0.66), true: 0
# [Row 1695] dysp predicted: 0 (conf: 0.80), true: 1
# [Row 1698] xray predicted: 1 (conf: 0.95), true: 0
# [Row 1700] smoke predicted: 1 (conf: 0.66), true: 0
# [Row 1707] bronc predicted: 0 (conf: 0.50), true: 1
# [Row 1737] bronc predicted: 0 (conf: 0.89), true: 1
# [Row 1742] dysp predicted: 0 (conf: 0.70), true: 1
# [Row 1747] smoke predicted: 0 (conf: 0.65), true: 1
# [Row 1748] smoke predicted: 0 (conf: 0.65), true: 1
# [Row 1757] dysp predicted: 0 (conf: 0.80), true: 1
# [Row 1771] smoke predicted: 1 (conf: 0.66), true: 0
# [Row 1775] smoke predicted: 1 (conf: 0.66), true: 0
# [Row 1797] dysp predicted: 0 (conf: 0.80), true: 1
# [Row 1808] dysp predicted: 0 (conf: 0.80), true: 1
# [Row 1832] dysp predicted: 0 (conf: 0.80), true: 1
# [Row 1833] smoke predicted: 0 (conf: 0.65), true: 1
# [Row 1857] smoke predicted: 1 (conf: 0.66), true: 0
# [Row 1858] dysp predicted: 1 (conf: 0.90), true: 0
# [Row 1862] dysp predicted: 1 (conf: 0.55), true: 0
# [Row 1872] xray predicted: 1 (conf: 0.95), true: 0
# [Row 1875] dysp predicted: 1 (conf: 0.90), true: 0
# [Row 1878] bronc predicted: 1 (conf: 0.82), true: 0
# [Row 1889] bronc predicted: 0 (conf: 0.89), true: 1
# [Row 1909] smoke predicted: 0 (conf: 0.65), true: 1
# [Row 1918] dysp predicted: 1 (conf: 0.90), true: 0
# [Row 1924] smoke predicted: 1 (conf: 0.66), true: 0
# [Row 1931] smoke predicted: 0 (conf: 0.60), true: 1
# [Row 1964] bronc predicted: 0 (conf: 0.50), true: 1
# [Row 1968] smoke predicted: 1 (conf: 0.66), true: 0
# [Row 1984] dysp predicted: 1 (conf: 0.55), true: 0
# [Row 1995] lung predicted: 0 (conf: 0.50), true: 1
#
# Final Accuracy: 0.8978
# Average Confidence: 0.8999
# (0.8977820636451301, 0.899873084751848)

# %%
data = "sachs"
evaluate_network(
    MODELS + f"{data}/{data}_complete.bif",
    DATA + f"{data}/test.csv",
    DATA + f"{data}/test_missing.csv",
    verbose=True
)
# Out:
# Evaluating: 100%|██████████| 2000/2000 [00:00<00:00, 2480.30it/s]
# Mismatches (687):
# [Row 5] Erk predicted: 2 (conf: 0.59), true: 1
# [Row 10] Akt predicted: 0 (conf: 0.82), true: 1
# [Row 10] PIP3 predicted: 0 (conf: 0.35), true: 1
# [Row 17] Erk predicted: 2 (conf: 0.59), true: 1
# [Row 20] Jnk predicted: 0 (conf: 0.33), true: 1
# [Row 20] Raf predicted: 1 (conf: 0.65), true: 0
# [Row 21] Jnk predicted: 0 (conf: 0.33), true: 1
# [Row 24] Erk predicted: 0 (conf: 0.47), true: 1
# [Row 26] Raf predicted: 0 (conf: 0.54), true: 2
# [Row 29] PIP3 predicted: 0 (conf: 0.35), true: 1
# [Row 31] Jnk predicted: 0 (conf: 0.33), true: 1
# [Row 34] PIP3 predicted: 0 (conf: 0.35), true: 1
# [Row 38] PKC predicted: 1 (conf: 0.44), true: 2
# [Row 40] P38 predicted: 0 (conf: 0.33), true: 1
# [Row 46] Erk predicted: 2 (conf: 0.59), true: 1
# [Row 48] P38 predicted: 0 (conf: 0.33), true: 2
# [Row 49] Jnk predicted: 0 (conf: 0.33), true: 1
# [Row 49] PKC predicted: 1 (conf: 0.70), true: 0
# [Row 50] Mek predicted: 2 (conf: 0.35), true: 0
# [Row 53] PIP3 predicted: 0 (conf: 0.39), true: 2
# [Row 54] Mek predicted: 2 (conf: 0.35), true: 0
# [Row 58] Jnk predicted: 0 (conf: 0.33), true: 1
# [Row 59] PKC predicted: 1 (conf: 0.74), true: 0
# [Row 66] Jnk predicted: 0 (conf: 0.33), true: 1
# [Row 68] Jnk predicted: 0 (conf: 0.33), true: 1
# [Row 68] PKC predicted: 1 (conf: 0.68), true: 2
# [Row 72] PIP2 predicted: 0 (conf: 0.33), true: 1
# [Row 75] PKA predicted: 2 (conf: 0.57), true: 1
# [Row 78] Jnk predicted: 0 (conf: 0.33), true: 1
# [Row 86] Jnk predicted: 0 (conf: 0.33), true: 2
# [Row 87] P38 predicted: 0 (conf: 0.33), true: 1
# [Row 93] PIP3 predicted: 0 (conf: 0.35), true: 1
# [Row 98] PIP3 predicted: 0 (conf: 0.35), true: 2
# [Row 100] Jnk predicted: 0 (conf: 0.33), true: 1
# [Row 101] Raf predicted: 0 (conf: 0.56), true: 1
# [Row 106] Jnk predicted: 0 (conf: 0.33), true: 2
# [Row 114] Akt predicted: 2 (conf: 0.88), true: 1
# [Row 118] Akt predicted: 0 (conf: 0.82), true: 1
# [Row 118] Mek predicted: 2 (conf: 0.35), true: 0
# [Row 120] PIP3 predicted: 0 (conf: 0.53), true: 1
# [Row 122] PIP3 predicted: 0 (conf: 0.35), true: 2
# [Row 126] Raf predicted: 2 (conf: 0.47), true: 0
# [Row 126] PIP3 predicted: 0 (conf: 0.35), true: 1
# [Row 129] PIP3 predicted: 2 (conf: 0.33), true: 1
# [Row 131] P38 predicted: 0 (conf: 0.33), true: 1
# [Row 133] Jnk predicted: 0 (conf: 0.33), true: 1
# [Row 134] Plcg predicted: 0 (conf: 0.54), true: 1
# [Row 135] PIP3 predicted: 0 (conf: 0.35), true: 2
# [Row 146] Erk predicted: 0 (conf: 0.47), true: 1
# [Row 148] Jnk predicted: 0 (conf: 0.33), true: 1
# [Row 149] PKA predicted: 2 (conf: 0.59), true: 1
# [Row 154] Erk predicted: 0 (conf: 0.48), true: 1
# [Row 154] PKA predicted: 2 (conf: 0.52), true: 1
# [Row 159] Mek predicted: 2 (conf: 0.35), true: 0
# [Row 173] Mek predicted: 0 (conf: 0.40), true: 1
# [Row 178] P38 predicted: 0 (conf: 0.33), true: 1
# [Row 180] P38 predicted: 0 (conf: 0.33), true: 1
# [Row 184] Plcg predicted: 0 (conf: 0.54), true: 1
# [Row 185] Erk predicted: 2 (conf: 0.59), true: 1
# [Row 185] Mek predicted: 2 (conf: 0.34), true: 0
# [Row 189] Jnk predicted: 0 (conf: 0.33), true: 1
# [Row 199] P38 predicted: 0 (conf: 0.33), true: 1
# [Row 202] PIP3 predicted: 0 (conf: 0.35), true: 1
# [Row 203] Mek predicted: 2 (conf: 0.38), true: 1
# [Row 205] Raf predicted: 1 (conf: 0.45), true: 2
# [Row 207] Mek predicted: 2 (conf: 0.38), true: 0
# [Row 209] PIP3 predicted: 0 (conf: 0.35), true: 1
# [Row 210] P38 predicted: 0 (conf: 0.33), true: 1
# [Row 211] PIP2 predicted: 0 (conf: 0.33), true: 1
# [Row 217] P38 predicted: 0 (conf: 0.33), true: 2
# [Row 219] PIP3 predicted: 0 (conf: 0.35), true: 2
# [Row 220] PKA predicted: 2 (conf: 0.59), true: 1
# [Row 223] Raf predicted: 1 (conf: 0.47), true: 0
# [Row 224] PKC predicted: 1 (conf: 0.44), true: 2
# [Row 224] P38 predicted: 0 (conf: 0.33), true: 1
# [Row 226] Akt predicted: 0 (conf: 0.67), true: 1
# [Row 226] PIP3 predicted: 0 (conf: 0.40), true: 1
# [Row 227] Erk predicted: 2 (conf: 0.59), true: 0
# [Row 227] Mek predicted: 2 (conf: 0.34), true: 0
# [Row 231] Mek predicted: 2 (conf: 0.35), true: 1
# [Row 237] Jnk predicted: 0 (conf: 0.33), true: 1
# [Row 238] PKC predicted: 1 (conf: 0.43), true: 0
# [Row 243] Jnk predicted: 0 (conf: 0.33), true: 1
# [Row 249] P38 predicted: 0 (conf: 0.33), true: 1
# [Row 250] PKA predicted: 2 (conf: 0.53), true: 1
# [Row 262] PKC predicted: 1 (conf: 0.56), true: 0
# [Row 268] PKC predicted: 1 (conf: 0.67), true: 0
# [Row 271] Raf predicted: 0 (conf: 0.54), true: 2
# [Row 273] P38 predicted: 0 (conf: 0.33), true: 1
# [Row 273] PIP3 predicted: 0 (conf: 0.35), true: 1
# [Row 284] Jnk predicted: 0 (conf: 0.33), true: 2
# [Row 284] Raf predicted: 0 (conf: 0.54), true: 2
# [Row 287] PIP2 predicted: 0 (conf: 0.33), true: 1
# [Row 290] Erk predicted: 1 (conf: 0.51), true: 0
# [Row 290] Mek predicted: 0 (conf: 0.34), true: 1
# [Row 295] Raf predicted: 1 (conf: 0.45), true: 2
# [Row 296] PIP3 predicted: 0 (conf: 0.35), true: 1
# [Row 298] Mek predicted: 2 (conf: 0.35), true: 0
# [Row 300] PKA predicted: 0 (conf: 0.69), true: 1
# [Row 301] PIP3 predicted: 0 (conf: 0.39), true: 2
# [Row 306] Erk predicted: 0 (conf: 0.67), true: 1
# [Row 309] PKA predicted: 2 (conf: 0.58), true: 1
# [Row 311] PIP2 predicted: 0 (conf: 0.33), true: 2
# [Row 316] PIP3 predicted: 0 (conf: 0.35), true: 1
# [Row 320] PIP2 predicted: 0 (conf: 0.33), true: 2
# [Row 323] Mek predicted: 2 (conf: 0.35), true: 0
# [Row 324] Raf predicted: 1 (conf: 0.34), true: 0
# [Row 325] Mek predicted: 2 (conf: 0.34), true: 1
# [Row 327] PKC predicted: 1 (conf: 0.48), true: 2
# [Row 330] PIP2 predicted: 0 (conf: 0.33), true: 1
# [Row 335] PIP3 predicted: 2 (conf: 0.33), true: 1
# [Row 340] PIP3 predicted: 0 (conf: 0.35), true: 2
# [Row 341] PKA predicted: 0 (conf: 0.66), true: 1
# [Row 345] Jnk predicted: 0 (conf: 0.33), true: 1
# [Row 350] PIP3 predicted: 0 (conf: 0.39), true: 1
# [Row 361] PIP3 predicted: 0 (conf: 0.35), true: 2
# [Row 362] PIP3 predicted: 0 (conf: 0.35), true: 2
# [Row 365] Raf predicted: 1 (conf: 0.34), true: 0
# [Row 367] Mek predicted: 1 (conf: 0.60), true: 2
# [Row 367] Raf predicted: 0 (conf: 0.37), true: 2
# [Row 371] Plcg predicted: 2 (conf: 0.76), true: 0
# [Row 374] PKC predicted: 1 (conf: 0.78), true: 0
# [Row 375] Erk predicted: 1 (conf: 0.69), true: 2
# [Row 375] Akt predicted: 0 (conf: 0.68), true: 1
# [Row 382] Jnk predicted: 0 (conf: 0.33), true: 1
# [Row 389] Mek predicted: 2 (conf: 0.35), true: 0
# [Row 390] Mek predicted: 2 (conf: 0.35), true: 0
# [Row 396] Raf predicted: 2 (conf: 0.44), true: 1
# [Row 398] Mek predicted: 2 (conf: 0.35), true: 0
# [Row 402] PIP2 predicted: 0 (conf: 0.33), true: 2
# [Row 405] P38 predicted: 0 (conf: 0.33), true: 2
# [Row 407] Jnk predicted: 0 (conf: 0.33), true: 1
# [Row 416] Mek predicted: 2 (conf: 0.35), true: 1
# [Row 416] PKC predicted: 1 (conf: 0.67), true: 0
# [Row 423] Mek predicted: 2 (conf: 0.35), true: 0
# [Row 424] PKA predicted: 0 (conf: 0.62), true: 1
# [Row 432] PKA predicted: 2 (conf: 0.74), true: 1
# [Row 432] Raf predicted: 0 (conf: 0.40), true: 1
# [Row 436] Akt predicted: 1 (conf: 0.81), true: 0
# [Row 436] Jnk predicted: 0 (conf: 0.33), true: 1
# [Row 438] Mek predicted: 2 (conf: 0.38), true: 1
# [Row 438] PIP3 predicted: 2 (conf: 0.53), true: 0
# [Row 439] PKA predicted: 2 (conf: 0.81), true: 1
# [Row 440] PKA predicted: 2 (conf: 0.58), true: 1
# [Row 442] Mek predicted: 2 (conf: 0.38), true: 0
# [Row 444] P38 predicted: 0 (conf: 0.33), true: 2
# [Row 446] PKA predicted: 1 (conf: 0.80), true: 2
# [Row 447] P38 predicted: 0 (conf: 0.33), true: 1
# [Row 448] Jnk predicted: 0 (conf: 0.33), true: 1
# [Row 450] Akt predicted: 0 (conf: 0.82), true: 1
# [Row 454] Erk predicted: 1 (conf: 0.51), true: 2
# [Row 454] P38 predicted: 0 (conf: 0.33), true: 1
# [Row 457] PKA predicted: 2 (conf: 0.60), true: 1
# [Row 461] Mek predicted: 2 (conf: 0.35), true: 0
# [Row 464] Akt predicted: 2 (conf: 0.88), true: 1
# [Row 466] Jnk predicted: 0 (conf: 0.33), true: 1
# [Row 466] PIP3 predicted: 0 (conf: 0.35), true: 1
# [Row 476] PKA predicted: 2 (conf: 0.50), true: 1
# [Row 477] Akt predicted: 0 (conf: 0.82), true: 1
# [Row 480] PKC predicted: 1 (conf: 0.44), true: 2
# [Row 482] Mek predicted: 0 (conf: 0.70), true: 1
# [Row 484] Mek predicted: 2 (conf: 0.35), true: 0
# [Row 487] Jnk predicted: 0 (conf: 0.33), true: 2
# [Row 489] Mek predicted: 0 (conf: 0.68), true: 1
# [Row 490] Jnk predicted: 0 (conf: 0.33), true: 1
# [Row 492] PIP3 predicted: 0 (conf: 0.35), true: 1
# [Row 498] Mek predicted: 2 (conf: 0.35), true: 1
# [Row 500] Jnk predicted: 0 (conf: 0.33), true: 2
# [Row 502] PKA predicted: 2 (conf: 0.74), true: 1
# [Row 504] Raf predicted: 1 (conf: 0.34), true: 0
# [Row 519] Raf predicted: 2 (conf: 0.47), true: 0
# [Row 520] Mek predicted: 2 (conf: 0.35), true: 0
# [Row 523] Erk predicted: 2 (conf: 0.59), true: 1
# [Row 527] Mek predicted: 2 (conf: 0.45), true: 0
# [Row 528] Raf predicted: 0 (conf: 0.56), true: 1
# [Row 529] Raf predicted: 1 (conf: 0.34), true: 0
# [Row 533] PIP3 predicted: 0 (conf: 0.35), true: 1
# [Row 535] Jnk predicted: 0 (conf: 0.33), true: 1
# [Row 539] PIP2 predicted: 0 (conf: 0.33), true: 1
# [Row 541] Akt predicted: 0 (conf: 0.82), true: 1
# [Row 543] Mek predicted: 1 (conf: 0.60), true: 2
# [Row 549] Raf predicted: 0 (conf: 0.54), true: 2
# [Row 551] Mek predicted: 0 (conf: 0.34), true: 1
# [Row 558] Erk predicted: 1 (conf: 0.51), true: 2
# [Row 559] Erk predicted: 2 (conf: 0.59), true: 0
# [Row 569] Jnk predicted: 0 (conf: 0.33), true: 1
# [Row 570] PIP3 predicted: 0 (conf: 0.40), true: 1
# [Row 573] PKC predicted: 1 (conf: 0.48), true: 2
# [Row 578] Raf predicted: 0 (conf: 0.55), true: 2
# [Row 580] Mek predicted: 2 (conf: 0.35), true: 0
# [Row 583] Mek predicted: 1 (conf: 0.60), true: 2
# [Row 584] Erk predicted: 0 (conf: 0.67), true: 1
# [Row 584] Raf predicted: 0 (conf: 0.54), true: 2
# [Row 595] Jnk predicted: 0 (conf: 0.33), true: 1
# [Row 599] Erk predicted: 1 (conf: 0.51), true: 0
# [Row 604] Erk predicted: 1 (conf: 0.73), true: 0
# [Row 604] Akt predicted: 0 (conf: 0.67), true: 1
# [Row 605] Mek predicted: 2 (conf: 0.38), true: 1
# [Row 605] Raf predicted: 2 (conf: 0.34), true: 1
# [Row 608] Jnk predicted: 0 (conf: 0.33), true: 1
# [Row 609] PKA predicted: 2 (conf: 0.49), true: 1
# [Row 617] P38 predicted: 0 (conf: 0.33), true: 1
# [Row 618] Jnk predicted: 0 (conf: 0.33), true: 1
# [Row 627] Mek predicted: 2 (conf: 0.38), true: 1
# [Row 630] PKC predicted: 1 (conf: 0.44), true: 2
# [Row 633] PIP3 predicted: 0 (conf: 0.35), true: 1
# [Row 634] Mek predicted: 2 (conf: 0.38), true: 0
# [Row 639] PIP3 predicted: 0 (conf: 0.35), true: 2
# [Row 641] Raf predicted: 2 (conf: 0.44), true: 0
# [Row 641] P38 predicted: 0 (conf: 0.33), true: 1
# [Row 642] PIP3 predicted: 0 (conf: 0.35), true: 1
# [Row 644] Akt predicted: 0 (conf: 0.62), true: 1
# [Row 646] P38 predicted: 0 (conf: 0.33), true: 2
# [Row 647] Jnk predicted: 0 (conf: 0.33), true: 2
# [Row 650] Erk predicted: 0 (conf: 0.67), true: 1
# [Row 655] PKC predicted: 0 (conf: 0.78), true: 1
# [Row 656] PKA predicted: 2 (conf: 0.85), true: 1
# [Row 659] Raf predicted: 0 (conf: 0.54), true: 2
# [Row 660] P38 predicted: 0 (conf: 0.33), true: 2
# [Row 663] P38 predicted: 0 (conf: 0.33), true: 2
# [Row 666] Raf predicted: 1 (conf: 0.34), true: 0
# [Row 670] Mek predicted: 1 (conf: 0.60), true: 2
# [Row 671] Erk predicted: 1 (conf: 0.51), true: 2
# [Row 680] Raf predicted: 1 (conf: 0.34), true: 0
# [Row 691] Mek predicted: 2 (conf: 0.35), true: 0
# [Row 694] Raf predicted: 0 (conf: 0.42), true: 1
# [Row 696] PKA predicted: 0 (conf: 0.49), true: 1
# [Row 696] PKC predicted: 0 (conf: 0.55), true: 1
# [Row 699] Jnk predicted: 0 (conf: 0.33), true: 1
# [Row 702] Erk predicted: 2 (conf: 0.59), true: 1
# [Row 705] PIP3 predicted: 0 (conf: 0.35), true: 1
# [Row 706] Akt predicted: 0 (conf: 0.82), true: 1
# [Row 706] PIP2 predicted: 0 (conf: 0.33), true: 1
# [Row 710] PIP3 predicted: 0 (conf: 0.35), true: 2
# [Row 711] Erk predicted: 1 (conf: 0.60), true: 2
# [Row 713] PIP2 predicted: 0 (conf: 0.33), true: 2
# [Row 713] Plcg predicted: 0 (conf: 0.85), true: 2
# [Row 717] P38 predicted: 0 (conf: 0.33), true: 2
# [Row 723] Erk predicted: 1 (conf: 0.60), true: 0
# [Row 727] Mek predicted: 2 (conf: 0.45), true: 0
# [Row 729] PKA predicted: 2 (conf: 0.58), true: 1
# [Row 732] Erk predicted: 0 (conf: 0.48), true: 1
# [Row 737] Plcg predicted: 0 (conf: 0.88), true: 1
# [Row 749] Raf predicted: 0 (conf: 0.54), true: 2
# [Row 751] Mek predicted: 2 (conf: 0.35), true: 1
# [Row 751] Jnk predicted: 0 (conf: 0.33), true: 1
# [Row 752] PKA predicted: 2 (conf: 0.75), true: 1
# [Row 752] P38 predicted: 0 (conf: 0.33), true: 1
# [Row 755] PKC predicted: 1 (conf: 0.78), true: 0
# [Row 758] Jnk predicted: 0 (conf: 0.33), true: 1
# [Row 759] Plcg predicted: 2 (conf: 0.97), true: 0
# [Row 765] PKC predicted: 1 (conf: 0.44), true: 0
# [Row 765] P38 predicted: 0 (conf: 0.33), true: 1
# [Row 766] PIP3 predicted: 0 (conf: 0.40), true: 1
# [Row 767] Plcg predicted: 0 (conf: 0.54), true: 1
# [Row 774] PIP2 predicted: 0 (conf: 0.33), true: 2
# [Row 777] Jnk predicted: 0 (conf: 0.33), true: 2
# [Row 782] Mek predicted: 2 (conf: 0.35), true: 0
# [Row 782] Plcg predicted: 0 (conf: 0.88), true: 1
# [Row 788] Erk predicted: 1 (conf: 0.51), true: 2
# [Row 793] PKA predicted: 2 (conf: 0.50), true: 1
# [Row 795] Mek predicted: 2 (conf: 0.35), true: 1
# [Row 796] PIP3 predicted: 0 (conf: 0.35), true: 2
# [Row 797] PKC predicted: 1 (conf: 0.74), true: 0
# [Row 808] Mek predicted: 2 (conf: 0.38), true: 0
# [Row 810] PKA predicted: 2 (conf: 0.50), true: 1
# [Row 813] Jnk predicted: 0 (conf: 0.33), true: 1
# [Row 814] PIP3 predicted: 0 (conf: 0.40), true: 2
# [Row 826] PKC predicted: 0 (conf: 0.83), true: 1
# [Row 830] Mek predicted: 2 (conf: 0.35), true: 0
# [Row 834] Akt predicted: 1 (conf: 0.81), true: 2
# [Row 834] Raf predicted: 1 (conf: 0.45), true: 0
# [Row 838] Jnk predicted: 0 (conf: 0.33), true: 1
# [Row 843] PKC predicted: 1 (conf: 0.44), true: 2
# [Row 843] PIP3 predicted: 0 (conf: 0.35), true: 1
# [Row 845] Akt predicted: 0 (conf: 0.82), true: 1
# [Row 850] PKA predicted: 2 (conf: 0.70), true: 1
# [Row 853] PIP3 predicted: 0 (conf: 0.35), true: 1
# [Row 856] Erk predicted: 1 (conf: 0.51), true: 2
# [Row 856] Mek predicted: 0 (conf: 0.34), true: 1
# [Row 859] Erk predicted: 0 (conf: 0.47), true: 1
# [Row 863] PKA predicted: 2 (conf: 0.51), true: 1
# [Row 864] Erk predicted: 1 (conf: 0.60), true: 0
# [Row 865] PIP3 predicted: 0 (conf: 0.35), true: 1
# [Row 870] Jnk predicted: 0 (conf: 0.33), true: 1
# [Row 875] Erk predicted: 2 (conf: 0.52), true: 1
# [Row 877] Jnk predicted: 0 (conf: 0.33), true: 1
# [Row 878] Jnk predicted: 0 (conf: 0.33), true: 1
# [Row 887] Jnk predicted: 0 (conf: 0.33), true: 1
# [Row 896] Erk predicted: 2 (conf: 0.59), true: 1
# [Row 896] Jnk predicted: 0 (conf: 0.33), true: 1
# [Row 900] PIP2 predicted: 0 (conf: 0.33), true: 2
# [Row 903] PIP2 predicted: 0 (conf: 0.33), true: 2
# [Row 907] Mek predicted: 2 (conf: 0.35), true: 0
# [Row 909] Jnk predicted: 0 (conf: 0.33), true: 1
# [Row 910] PIP3 predicted: 0 (conf: 0.35), true: 1
# [Row 912] Mek predicted: 2 (conf: 0.35), true: 1
# [Row 913] Mek predicted: 1 (conf: 0.60), true: 2
# [Row 916] Erk predicted: 2 (conf: 0.59), true: 1
# [Row 917] Mek predicted: 2 (conf: 0.38), true: 0
# [Row 918] Mek predicted: 2 (conf: 0.35), true: 0
# [Row 924] Mek predicted: 2 (conf: 0.54), true: 1
# [Row 928] PIP3 predicted: 0 (conf: 0.35), true: 1
# [Row 933] Mek predicted: 2 (conf: 0.35), true: 0
# [Row 934] Jnk predicted: 0 (conf: 0.33), true: 1
# [Row 936] PKC predicted: 1 (conf: 0.67), true: 0
# [Row 939] PIP2 predicted: 0 (conf: 0.33), true: 1
# [Row 941] Jnk predicted: 0 (conf: 0.33), true: 1
# [Row 945] Jnk predicted: 0 (conf: 0.33), true: 2
# [Row 945] PIP3 predicted: 2 (conf: 0.88), true: 0
# [Row 948] Erk predicted: 0 (conf: 0.48), true: 1
# [Row 950] PKA predicted: 0 (conf: 0.62), true: 1
# [Row 951] Akt predicted: 1 (conf: 0.59), true: 2
# [Row 955] Mek predicted: 2 (conf: 0.35), true: 0
# [Row 959] Jnk predicted: 0 (conf: 0.33), true: 1
# [Row 963] Raf predicted: 1 (conf: 0.45), true: 0
# [Row 965] Mek predicted: 2 (conf: 0.38), true: 1
# [Row 969] P38 predicted: 0 (conf: 0.33), true: 1
# [Row 976] Akt predicted: 0 (conf: 0.82), true: 1
# [Row 976] Jnk predicted: 0 (conf: 0.33), true: 1
# [Row 978] Erk predicted: 1 (conf: 0.51), true: 2
# [Row 981] Erk predicted: 0 (conf: 0.48), true: 1
# [Row 986] Jnk predicted: 0 (conf: 0.33), true: 2
# [Row 989] Mek predicted: 2 (conf: 0.35), true: 0
# [Row 994] PKA predicted: 2 (conf: 0.79), true: 1
# [Row 995] Erk predicted: 0 (conf: 0.48), true: 1
# [Row 997] Akt predicted: 2 (conf: 0.88), true: 1
# [Row 1007] PIP2 predicted: 0 (conf: 0.33), true: 1
# [Row 1015] PIP3 predicted: 0 (conf: 0.35), true: 1
# [Row 1016] PIP3 predicted: 0 (conf: 0.35), true: 2
# [Row 1024] Erk predicted: 1 (conf: 0.73), true: 0
# [Row 1024] Akt predicted: 0 (conf: 0.67), true: 1
# [Row 1026] PKA predicted: 2 (conf: 0.61), true: 1
# [Row 1026] Raf predicted: 1 (conf: 0.47), true: 0
# [Row 1031] P38 predicted: 0 (conf: 0.33), true: 1
# [Row 1035] PIP2 predicted: 0 (conf: 0.33), true: 1
# [Row 1036] Mek predicted: 2 (conf: 0.38), true: 1
# [Row 1039] PIP3 predicted: 0 (conf: 0.35), true: 1
# [Row 1044] Erk predicted: 0 (conf: 0.47), true: 1
# [Row 1046] Mek predicted: 2 (conf: 0.35), true: 1
# [Row 1046] Raf predicted: 2 (conf: 0.34), true: 1
# [Row 1047] PIP3 predicted: 0 (conf: 0.39), true: 1
# [Row 1050] Mek predicted: 2 (conf: 0.35), true: 1
# [Row 1050] PIP3 predicted: 0 (conf: 0.35), true: 2
# [Row 1055] PIP3 predicted: 0 (conf: 0.35), true: 1
# [Row 1058] PKC predicted: 1 (conf: 0.72), true: 0
# [Row 1063] Mek predicted: 2 (conf: 0.35), true: 0
# [Row 1066] Mek predicted: 2 (conf: 0.35), true: 0
# [Row 1067] PIP3 predicted: 0 (conf: 0.35), true: 1
# [Row 1069] PIP2 predicted: 0 (conf: 0.33), true: 2
# [Row 1072] PIP3 predicted: 0 (conf: 0.53), true: 1
# [Row 1075] Raf predicted: 1 (conf: 0.47), true: 0
# [Row 1078] Raf predicted: 2 (conf: 0.60), true: 1
# [Row 1080] PIP3 predicted: 0 (conf: 0.35), true: 1
# [Row 1087] PIP3 predicted: 0 (conf: 0.35), true: 1
# [Row 1088] Jnk predicted: 0 (conf: 0.33), true: 1
# [Row 1091] PIP3 predicted: 2 (conf: 0.33), true: 1
# [Row 1099] Erk predicted: 0 (conf: 0.48), true: 1
# [Row 1101] PIP3 predicted: 0 (conf: 0.35), true: 1
# [Row 1107] Jnk predicted: 0 (conf: 0.33), true: 1
# [Row 1110] Mek predicted: 2 (conf: 0.35), true: 1
# [Row 1111] Erk predicted: 2 (conf: 0.59), true: 1
# [Row 1113] PIP3 predicted: 0 (conf: 0.35), true: 1
# [Row 1115] Raf predicted: 1 (conf: 0.45), true: 0
# [Row 1115] P38 predicted: 0 (conf: 0.33), true: 1
# [Row 1116] Jnk predicted: 0 (conf: 0.33), true: 2
# [Row 1120] P38 predicted: 0 (conf: 0.33), true: 1
# [Row 1122] Mek predicted: 0 (conf: 0.40), true: 1
# [Row 1124] Raf predicted: 2 (conf: 0.60), true: 1
# [Row 1127] Erk predicted: 1 (conf: 0.51), true: 0
# [Row 1130] PIP3 predicted: 0 (conf: 0.35), true: 2
# [Row 1133] Jnk predicted: 0 (conf: 0.33), true: 1
# [Row 1133] Raf predicted: 0 (conf: 0.56), true: 1
# [Row 1138] PIP3 predicted: 0 (conf: 0.39), true: 1
# [Row 1143] Mek predicted: 2 (conf: 0.45), true: 0
# [Row 1143] Raf predicted: 2 (conf: 0.37), true: 0
# [Row 1147] Erk predicted: 0 (conf: 0.67), true: 1
# [Row 1148] PKA predicted: 0 (conf: 0.50), true: 1
# [Row 1148] PKC predicted: 1 (conf: 0.56), true: 0
# [Row 1149] Mek predicted: 2 (conf: 0.35), true: 0
# [Row 1150] Jnk predicted: 0 (conf: 0.33), true: 1
# [Row 1152] Raf predicted: 2 (conf: 0.38), true: 1
# [Row 1155] Erk predicted: 0 (conf: 0.47), true: 1
# [Row 1157] PKA predicted: 2 (conf: 0.58), true: 1
# [Row 1158] Jnk predicted: 0 (conf: 0.33), true: 1
# [Row 1162] PIP3 predicted: 0 (conf: 0.35), true: 1
# [Row 1165] PIP3 predicted: 0 (conf: 0.35), true: 2
# [Row 1166] Mek predicted: 2 (conf: 0.35), true: 1
# [Row 1167] Mek predicted: 2 (conf: 0.38), true: 1
# [Row 1167] Raf predicted: 2 (conf: 0.34), true: 1
# [Row 1173] Erk predicted: 0 (conf: 0.47), true: 1
# [Row 1174] P38 predicted: 0 (conf: 0.33), true: 1
# [Row 1175] Mek predicted: 2 (conf: 0.35), true: 1
# [Row 1179] Raf predicted: 0 (conf: 0.54), true: 2
# [Row 1185] Jnk predicted: 0 (conf: 0.33), true: 1
# [Row 1186] PKA predicted: 0 (conf: 0.68), true: 1
# [Row 1188] Mek predicted: 2 (conf: 0.38), true: 0
# [Row 1189] P38 predicted: 0 (conf: 0.33), true: 1
# [Row 1191] Mek predicted: 2 (conf: 0.38), true: 0
# [Row 1192] PIP2 predicted: 0 (conf: 0.33), true: 2
# [Row 1193] PKA predicted: 2 (conf: 0.58), true: 1
# [Row 1196] Mek predicted: 2 (conf: 0.35), true: 0
# [Row 1198] Erk predicted: 1 (conf: 0.60), true: 2
# [Row 1199] Akt predicted: 0 (conf: 0.82), true: 1
# [Row 1205] PIP3 predicted: 0 (conf: 0.35), true: 1
# [Row 1208] Plcg predicted: 0 (conf: 0.54), true: 1
# [Row 1209] Erk predicted: 0 (conf: 0.47), true: 1
# [Row 1210] PIP3 predicted: 0 (conf: 0.35), true: 2
# [Row 1212] Akt predicted: 0 (conf: 0.82), true: 1
# [Row 1216] PKC predicted: 1 (conf: 0.56), true: 2
# [Row 1219] PIP3 predicted: 2 (conf: 0.53), true: 1
# [Row 1221] PIP2 predicted: 0 (conf: 0.33), true: 1
# [Row 1224] Plcg predicted: 0 (conf: 0.92), true: 1
# [Row 1226] PIP3 predicted: 0 (conf: 0.35), true: 2
# [Row 1240] Mek predicted: 2 (conf: 0.35), true: 0
# [Row 1242] Mek predicted: 2 (conf: 0.35), true: 0
# [Row 1249] Jnk predicted: 0 (conf: 0.33), true: 1
# [Row 1256] Akt predicted: 0 (conf: 0.82), true: 1
# [Row 1256] Mek predicted: 2 (conf: 0.35), true: 0
# [Row 1261] Erk predicted: 2 (conf: 0.52), true: 1
# [Row 1263] Mek predicted: 2 (conf: 0.35), true: 0
# [Row 1263] PIP3 predicted: 0 (conf: 0.35), true: 2
# [Row 1264] Mek predicted: 2 (conf: 0.38), true: 1
# [Row 1282] Akt predicted: 0 (conf: 0.82), true: 1
# [Row 1285] PKC predicted: 0 (conf: 0.83), true: 1
# [Row 1286] Raf predicted: 2 (conf: 0.44), true: 0
# [Row 1293] PKA predicted: 0 (conf: 0.87), true: 1
# [Row 1294] Mek predicted: 2 (conf: 0.35), true: 1
# [Row 1295] Akt predicted: 0 (conf: 0.82), true: 1
# [Row 1300] PKC predicted: 1 (conf: 0.72), true: 0
# [Row 1303] Jnk predicted: 0 (conf: 0.33), true: 1
# [Row 1304] Mek predicted: 1 (conf: 0.60), true: 2
# [Row 1305] Raf predicted: 0 (conf: 0.43), true: 1
# [Row 1306] Akt predicted: 2 (conf: 0.88), true: 1
# [Row 1312] Mek predicted: 2 (conf: 0.35), true: 0
# [Row 1312] Raf predicted: 1 (conf: 0.34), true: 2
# [Row 1313] Raf predicted: 2 (conf: 0.44), true: 0
# [Row 1316] P38 predicted: 0 (conf: 0.33), true: 1
# [Row 1317] PKC predicted: 1 (conf: 0.44), true: 0
# [Row 1317] PIP3 predicted: 0 (conf: 0.35), true: 2
# [Row 1324] P38 predicted: 0 (conf: 0.33), true: 1
# [Row 1324] PIP3 predicted: 0 (conf: 0.35), true: 1
# [Row 1325] Jnk predicted: 0 (conf: 0.33), true: 1
# [Row 1327] Raf predicted: 1 (conf: 0.34), true: 0
# [Row 1329] Raf predicted: 1 (conf: 0.34), true: 2
# [Row 1333] PKA predicted: 2 (conf: 0.53), true: 1
# [Row 1334] P38 predicted: 0 (conf: 0.33), true: 1
# [Row 1334] PIP3 predicted: 0 (conf: 0.35), true: 2
# [Row 1335] PIP3 predicted: 0 (conf: 0.39), true: 1
# [Row 1341] Raf predicted: 1 (conf: 0.45), true: 2
# [Row 1344] PKC predicted: 0 (conf: 0.97), true: 1
# [Row 1346] PKC predicted: 1 (conf: 0.48), true: 2
# [Row 1348] Mek predicted: 2 (conf: 0.35), true: 0
# [Row 1348] PIP2 predicted: 0 (conf: 0.33), true: 1
# [Row 1350] P38 predicted: 0 (conf: 0.33), true: 2
# [Row 1351] PKA predicted: 1 (conf: 0.51), true: 2
# [Row 1354] Jnk predicted: 0 (conf: 0.33), true: 1
# [Row 1356] Erk predicted: 2 (conf: 0.59), true: 1
# [Row 1358] Mek predicted: 0 (conf: 0.40), true: 1
# [Row 1359] Raf predicted: 1 (conf: 0.45), true: 0
# [Row 1361] Raf predicted: 0 (conf: 0.54), true: 1
# [Row 1364] Mek predicted: 2 (conf: 0.35), true: 0
# [Row 1370] PIP3 predicted: 0 (conf: 0.39), true: 1
# [Row 1371] Erk predicted: 2 (conf: 0.59), true: 0
# [Row 1372] P38 predicted: 0 (conf: 0.33), true: 1
# [Row 1377] PIP3 predicted: 2 (conf: 0.33), true: 1
# [Row 1383] PIP3 predicted: 0 (conf: 0.35), true: 1
# [Row 1386] Erk predicted: 0 (conf: 0.47), true: 1
# [Row 1389] P38 predicted: 0 (conf: 0.33), true: 2
# [Row 1393] Raf predicted: 0 (conf: 0.54), true: 2
# [Row 1397] Plcg predicted: 0 (conf: 0.92), true: 2
# [Row 1401] Erk predicted: 1 (conf: 0.60), true: 0
# [Row 1406] P38 predicted: 0 (conf: 0.33), true: 2
# [Row 1409] PKA predicted: 0 (conf: 0.75), true: 1
# [Row 1415] Mek predicted: 2 (conf: 0.35), true: 0
# [Row 1417] Mek predicted: 2 (conf: 0.38), true: 0
# [Row 1419] Jnk predicted: 0 (conf: 0.33), true: 1
# [Row 1421] PIP3 predicted: 0 (conf: 0.35), true: 1
# [Row 1426] Raf predicted: 2 (conf: 0.60), true: 1
# [Row 1430] PIP3 predicted: 0 (conf: 0.35), true: 2
# [Row 1435] Raf predicted: 1 (conf: 0.65), true: 0
# [Row 1435] PIP2 predicted: 0 (conf: 0.33), true: 1
# [Row 1436] Raf predicted: 2 (conf: 0.44), true: 0
# [Row 1439] Raf predicted: 1 (conf: 0.34), true: 0
# [Row 1447] Mek predicted: 2 (conf: 0.35), true: 0
# [Row 1459] Jnk predicted: 0 (conf: 0.33), true: 1
# [Row 1464] PKC predicted: 1 (conf: 0.48), true: 2
# [Row 1464] Plcg predicted: 0 (conf: 0.88), true: 1
# [Row 1469] Raf predicted: 2 (conf: 0.47), true: 0
# [Row 1471] PIP2 predicted: 0 (conf: 0.33), true: 1
# [Row 1476] Mek predicted: 2 (conf: 0.35), true: 1
# [Row 1477] PKA predicted: 2 (conf: 0.62), true: 1
# [Row 1483] Erk predicted: 2 (conf: 0.59), true: 1
# [Row 1489] P38 predicted: 0 (conf: 0.33), true: 1
# [Row 1491] Jnk predicted: 0 (conf: 0.33), true: 1
# [Row 1493] Raf predicted: 2 (conf: 0.60), true: 1
# [Row 1494] Raf predicted: 0 (conf: 0.56), true: 1
# [Row 1494] PIP3 predicted: 0 (conf: 0.40), true: 1
# [Row 1499] Raf predicted: 1 (conf: 0.45), true: 2
# [Row 1501] Jnk predicted: 0 (conf: 0.33), true: 1
# [Row 1503] P38 predicted: 0 (conf: 0.33), true: 2
# [Row 1505] PIP3 predicted: 0 (conf: 0.35), true: 2
# [Row 1506] Mek predicted: 2 (conf: 0.35), true: 1
# [Row 1507] Jnk predicted: 0 (conf: 0.33), true: 1
# [Row 1508] Raf predicted: 1 (conf: 0.45), true: 0
# [Row 1509] Mek predicted: 2 (conf: 0.35), true: 0
# [Row 1512] PKA predicted: 2 (conf: 0.95), true: 1
# [Row 1512] PIP3 predicted: 0 (conf: 0.35), true: 1
# [Row 1517] Jnk predicted: 0 (conf: 0.33), true: 1
# [Row 1519] Mek predicted: 0 (conf: 0.70), true: 1
# [Row 1524] Akt predicted: 1 (conf: 0.66), true: 0
# [Row 1524] Mek predicted: 1 (conf: 0.60), true: 0
# [Row 1525] Jnk predicted: 0 (conf: 0.33), true: 1
# [Row 1532] Akt predicted: 1 (conf: 0.59), true: 2
# [Row 1533] Mek predicted: 0 (conf: 0.40), true: 1
# [Row 1536] Mek predicted: 2 (conf: 0.45), true: 0
# [Row 1537] Plcg predicted: 0 (conf: 0.44), true: 1
# [Row 1541] Jnk predicted: 0 (conf: 0.33), true: 1
# [Row 1542] Jnk predicted: 0 (conf: 0.33), true: 1
# [Row 1544] PIP3 predicted: 2 (conf: 0.53), true: 1
# [Row 1546] PIP3 predicted: 0 (conf: 0.35), true: 1
# [Row 1553] Mek predicted: 0 (conf: 0.34), true: 1
# [Row 1554] PKA predicted: 1 (conf: 0.84), true: 0
# [Row 1556] Jnk predicted: 0 (conf: 0.33), true: 1
# [Row 1563] PKC predicted: 1 (conf: 0.67), true: 0
# [Row 1564] PIP3 predicted: 0 (conf: 0.35), true: 2
# [Row 1566] Jnk predicted: 0 (conf: 0.33), true: 1
# [Row 1568] Mek predicted: 2 (conf: 0.45), true: 0
# [Row 1569] PKC predicted: 1 (conf: 0.44), true: 2
# [Row 1574] Jnk predicted: 0 (conf: 0.33), true: 1
# [Row 1578] Raf predicted: 1 (conf: 0.34), true: 0
# [Row 1579] PKA predicted: 2 (conf: 0.53), true: 1
# [Row 1580] Raf predicted: 1 (conf: 0.45), true: 0
# [Row 1587] PIP3 predicted: 0 (conf: 0.39), true: 1
# [Row 1599] PIP2 predicted: 0 (conf: 0.33), true: 1
# [Row 1600] Raf predicted: 1 (conf: 0.34), true: 0
# [Row 1602] Mek predicted: 2 (conf: 0.35), true: 1
# [Row 1605] P38 predicted: 0 (conf: 0.33), true: 1
# [Row 1609] Jnk predicted: 0 (conf: 0.33), true: 2
# [Row 1612] PIP3 predicted: 0 (conf: 0.35), true: 2
# [Row 1613] Erk predicted: 2 (conf: 0.59), true: 1
# [Row 1616] Mek predicted: 2 (conf: 0.35), true: 0
# [Row 1622] Mek predicted: 2 (conf: 0.35), true: 1
# [Row 1627] PKC predicted: 1 (conf: 0.56), true: 2
# [Row 1629] Mek predicted: 2 (conf: 0.38), true: 1
# [Row 1635] PIP3 predicted: 0 (conf: 0.35), true: 2
# [Row 1636] PIP2 predicted: 0 (conf: 0.33), true: 1
# [Row 1642] PKA predicted: 0 (conf: 0.43), true: 1
# [Row 1644] PIP3 predicted: 2 (conf: 0.33), true: 1
# [Row 1648] Mek predicted: 2 (conf: 0.45), true: 0
# [Row 1648] Raf predicted: 2 (conf: 0.37), true: 0
# [Row 1653] Mek predicted: 2 (conf: 0.38), true: 1
# [Row 1654] PKA predicted: 2 (conf: 0.83), true: 1
# [Row 1655] Mek predicted: 2 (conf: 0.35), true: 1
# [Row 1655] PIP2 predicted: 0 (conf: 0.33), true: 2
# [Row 1658] Mek predicted: 0 (conf: 0.40), true: 2
# [Row 1659] Mek predicted: 2 (conf: 0.35), true: 0
# [Row 1659] PIP3 predicted: 0 (conf: 0.35), true: 2
# [Row 1661] Akt predicted: 1 (conf: 0.81), true: 0
# [Row 1661] Jnk predicted: 0 (conf: 0.33), true: 1
# [Row 1670] PIP3 predicted: 0 (conf: 0.35), true: 1
# [Row 1672] PIP3 predicted: 0 (conf: 0.35), true: 2
# [Row 1676] Raf predicted: 2 (conf: 0.44), true: 0
# [Row 1681] PIP3 predicted: 0 (conf: 0.35), true: 1
# [Row 1686] PIP3 predicted: 0 (conf: 0.35), true: 1
# [Row 1688] Mek predicted: 2 (conf: 0.45), true: 0
# [Row 1689] P38 predicted: 0 (conf: 0.33), true: 2
# [Row 1690] PIP3 predicted: 0 (conf: 0.35), true: 1
# [Row 1691] Jnk predicted: 0 (conf: 0.33), true: 1
# [Row 1692] Erk predicted: 0 (conf: 0.47), true: 1
# [Row 1695] Raf predicted: 0 (conf: 0.54), true: 1
# [Row 1696] PIP3 predicted: 2 (conf: 0.33), true: 1
# [Row 1697] Jnk predicted: 0 (conf: 0.33), true: 2
# [Row 1699] PIP3 predicted: 0 (conf: 0.35), true: 1
# [Row 1704] PKA predicted: 2 (conf: 0.53), true: 1
# [Row 1710] Erk predicted: 1 (conf: 0.69), true: 2
# [Row 1710] Akt predicted: 0 (conf: 0.68), true: 1
# [Row 1714] PIP3 predicted: 0 (conf: 0.35), true: 1
# [Row 1715] Mek predicted: 2 (conf: 0.85), true: 1
# [Row 1718] PIP3 predicted: 2 (conf: 0.33), true: 0
# [Row 1721] PIP3 predicted: 0 (conf: 0.35), true: 1
# [Row 1722] Mek predicted: 0 (conf: 0.70), true: 1
# [Row 1724] Raf predicted: 1 (conf: 0.45), true: 0
# [Row 1725] P38 predicted: 0 (conf: 0.33), true: 2
# [Row 1727] Mek predicted: 2 (conf: 0.35), true: 0
# [Row 1732] Jnk predicted: 0 (conf: 0.33), true: 1
# [Row 1734] Jnk predicted: 0 (conf: 0.33), true: 1
# [Row 1738] PIP3 predicted: 0 (conf: 0.40), true: 2
# [Row 1739] PKC predicted: 1 (conf: 0.78), true: 0
# [Row 1740] PIP3 predicted: 2 (conf: 0.53), true: 1
# [Row 1742] Erk predicted: 2 (conf: 0.59), true: 1
# [Row 1747] PIP2 predicted: 0 (conf: 0.33), true: 1
# [Row 1748] Mek predicted: 0 (conf: 0.68), true: 1
# [Row 1749] PIP3 predicted: 0 (conf: 0.35), true: 1
# [Row 1750] Mek predicted: 2 (conf: 0.54), true: 0
# [Row 1751] PKC predicted: 1 (conf: 0.44), true: 0
# [Row 1751] PIP3 predicted: 0 (conf: 0.53), true: 1
# [Row 1753] Raf predicted: 1 (conf: 0.47), true: 0
# [Row 1754] Jnk predicted: 0 (conf: 0.33), true: 1
# [Row 1758] PKC predicted: 1 (conf: 0.51), true: 0
# [Row 1760] P38 predicted: 0 (conf: 0.33), true: 1
# [Row 1760] PIP2 predicted: 0 (conf: 0.33), true: 1
# [Row 1761] Akt predicted: 0 (conf: 0.68), true: 1
# [Row 1763] Raf predicted: 2 (conf: 0.44), true: 0
# [Row 1766] PIP3 predicted: 0 (conf: 0.35), true: 2
# [Row 1767] Raf predicted: 1 (conf: 0.34), true: 0
# [Row 1768] Erk predicted: 1 (conf: 0.51), true: 0
# [Row 1773] PKC predicted: 1 (conf: 0.78), true: 0
# [Row 1778] Jnk predicted: 0 (conf: 0.33), true: 1
# [Row 1779] PIP3 predicted: 0 (conf: 0.35), true: 1
# [Row 1782] P38 predicted: 0 (conf: 0.33), true: 2
# [Row 1786] Raf predicted: 1 (conf: 0.65), true: 2
# [Row 1788] Raf predicted: 0 (conf: 0.54), true: 2
# [Row 1789] Raf predicted: 2 (conf: 0.44), true: 1
# [Row 1791] Mek predicted: 2 (conf: 0.35), true: 0
# [Row 1791] Raf predicted: 2 (conf: 0.34), true: 1
# [Row 1793] Mek predicted: 2 (conf: 0.35), true: 0
# [Row 1793] Raf predicted: 2 (conf: 0.34), true: 0
# [Row 1794] Raf predicted: 1 (conf: 0.45), true: 0
# [Row 1803] Mek predicted: 0 (conf: 0.40), true: 1
# [Row 1812] Jnk predicted: 0 (conf: 0.33), true: 1
# [Row 1814] Mek predicted: 2 (conf: 0.45), true: 0
# [Row 1839] Jnk predicted: 0 (conf: 0.33), true: 1
# [Row 1839] PIP3 predicted: 0 (conf: 0.35), true: 1
# [Row 1848] Jnk predicted: 0 (conf: 0.33), true: 1
# [Row 1848] PKC predicted: 1 (conf: 0.68), true: 2
# [Row 1854] Mek predicted: 2 (conf: 0.45), true: 0
# [Row 1855] PIP3 predicted: 0 (conf: 0.35), true: 1
# [Row 1861] PKC predicted: 1 (conf: 0.44), true: 2
# [Row 1867] P38 predicted: 0 (conf: 0.33), true: 1
# [Row 1873] Raf predicted: 0 (conf: 0.54), true: 2
# [Row 1876] PIP3 predicted: 0 (conf: 0.39), true: 1
# [Row 1877] Erk predicted: 2 (conf: 0.59), true: 1
# [Row 1884] Akt predicted: 1 (conf: 0.59), true: 0
# [Row 1887] Mek predicted: 2 (conf: 0.38), true: 0
# [Row 1887] Raf predicted: 1 (conf: 0.35), true: 2
# [Row 1888] PKC predicted: 1 (conf: 0.52), true: 2
# [Row 1893] P38 predicted: 0 (conf: 0.33), true: 1
# [Row 1894] Mek predicted: 2 (conf: 0.35), true: 0
# [Row 1895] Mek predicted: 2 (conf: 0.35), true: 0
# [Row 1897] PIP3 predicted: 0 (conf: 0.35), true: 2
# [Row 1900] Akt predicted: 0 (conf: 0.82), true: 1
# [Row 1903] Raf predicted: 1 (conf: 0.65), true: 2
# [Row 1908] PKA predicted: 0 (conf: 0.55), true: 1
# [Row 1909] Jnk predicted: 0 (conf: 0.33), true: 1
# [Row 1910] PIP3 predicted: 2 (conf: 0.54), true: 1
# [Row 1912] Mek predicted: 2 (conf: 0.35), true: 0
# [Row 1916] P38 predicted: 0 (conf: 0.33), true: 1
# [Row 1920] P38 predicted: 0 (conf: 0.33), true: 1
# [Row 1921] Akt predicted: 0 (conf: 0.82), true: 1
# [Row 1921] Mek predicted: 2 (conf: 0.35), true: 0
# [Row 1923] Jnk predicted: 0 (conf: 0.33), true: 1
# [Row 1925] PIP3 predicted: 0 (conf: 0.35), true: 1
# [Row 1930] Erk predicted: 0 (conf: 0.67), true: 1
# [Row 1932] PIP3 predicted: 0 (conf: 0.35), true: 1
# [Row 1936] PIP3 predicted: 2 (conf: 0.33), true: 0
# [Row 1938] PKA predicted: 0 (conf: 0.67), true: 1
# [Row 1940] Mek predicted: 2 (conf: 0.38), true: 0
# [Row 1941] PIP3 predicted: 0 (conf: 0.35), true: 1
# [Row 1942] PIP3 predicted: 0 (conf: 0.35), true: 2
# [Row 1943] PIP3 predicted: 0 (conf: 0.35), true: 2
# [Row 1944] P38 predicted: 0 (conf: 0.33), true: 1
# [Row 1949] Mek predicted: 2 (conf: 0.35), true: 1
# [Row 1951] Akt predicted: 0 (conf: 0.62), true: 1
# [Row 1952] PIP3 predicted: 0 (conf: 0.35), true: 2
# [Row 1953] Mek predicted: 2 (conf: 0.35), true: 0
# [Row 1954] Mek predicted: 2 (conf: 0.38), true: 1
# [Row 1960] Mek predicted: 1 (conf: 0.60), true: 2
# [Row 1961] Raf predicted: 1 (conf: 0.34), true: 0
# [Row 1961] P38 predicted: 0 (conf: 0.33), true: 1
# [Row 1968] Mek predicted: 2 (conf: 0.38), true: 1
# [Row 1973] Jnk predicted: 0 (conf: 0.33), true: 1
# [Row 1973] Raf predicted: 0 (conf: 0.56), true: 1
# [Row 1974] Mek predicted: 2 (conf: 0.38), true: 1
# [Row 1974] PIP3 predicted: 0 (conf: 0.53), true: 1
# [Row 1979] Erk predicted: 2 (conf: 0.59), true: 1
# [Row 1979] Mek predicted: 2 (conf: 0.34), true: 1
# [Row 1981] Mek predicted: 2 (conf: 0.45), true: 0
# [Row 1982] Jnk predicted: 0 (conf: 0.33), true: 2
# [Row 1984] Mek predicted: 2 (conf: 0.35), true: 0
# [Row 1985] Jnk predicted: 0 (conf: 0.33), true: 1
# [Row 1986] PIP3 predicted: 0 (conf: 0.35), true: 2
# [Row 1991] PKA predicted: 1 (conf: 0.81), true: 0
# [Row 1993] PKA predicted: 0 (conf: 0.65), true: 1
# [Row 1996] Jnk predicted: 0 (conf: 0.33), true: 1
# [Row 1998] Jnk predicted: 0 (conf: 0.33), true: 1
# [Row 1999] PIP3 predicted: 0 (conf: 0.35), true: 2
#
# Final Accuracy: 0.6513
# Average Confidence: 0.5635
# (0.651269035532995, 0.5634955157077822)

# %%
data = "sprinkler"
evaluate_network(
    MODELS + f"{data}/{data}_complete.bif",
    DATA + f"{data}/test.csv",
    DATA + f"{data}/test_missing.csv",
    verbose=True
)
# Out:
# Evaluating: 100%|██████████| 200/200 [00:00<00:00, 5655.79it/s]
# Mismatches (38):
# [Row 0] Sprinkler predicted: 1 (conf: 0.52), true: 0
# [Row 1] Sprinkler predicted: 1 (conf: 0.52), true: 0
# [Row 8] Cloudy predicted: 1 (conf: 0.88), true: 0
# [Row 17] Rain predicted: 0 (conf: 0.71), true: 1
# [Row 51] Sprinkler predicted: 0 (conf: 0.90), true: 1
# [Row 66] Cloudy predicted: 1 (conf: 0.79), true: 0
# [Row 88] Sprinkler predicted: 0 (conf: 0.91), true: 1
# [Row 92] Sprinkler predicted: 1 (conf: 0.52), true: 0
# [Row 95] Cloudy predicted: 0 (conf: 0.56), true: 1
# [Row 98] Rain predicted: 1 (conf: 0.52), true: 0
# [Row 105] Cloudy predicted: 1 (conf: 0.79), true: 0
# [Row 109] Wet_Grass predicted: 1 (conf: 0.90), true: 0
# [Row 113] Sprinkler predicted: 0 (conf: 0.50), true: 1
# [Row 113] Wet_Grass predicted: 0 (conf: 0.55), true: 1
# [Row 117] Cloudy predicted: 0 (conf: 0.71), true: 1
# [Row 131] Wet_Grass predicted: 1 (conf: 0.91), true: 0
# [Row 134] Wet_Grass predicted: 1 (conf: 0.92), true: 0
# [Row 136] Sprinkler predicted: 1 (conf: 0.52), true: 0
# [Row 138] Sprinkler predicted: 0 (conf: 0.50), true: 1
# [Row 138] Wet_Grass predicted: 0 (conf: 0.55), true: 1
# [Row 141] Sprinkler predicted: 1 (conf: 0.52), true: 0
# [Row 147] Cloudy predicted: 0 (conf: 0.69), true: 1
# [Row 150] Rain predicted: 1 (conf: 0.80), true: 0
# [Row 150] Wet_Grass predicted: 1 (conf: 0.72), true: 0
# [Row 151] Cloudy predicted: 0 (conf: 0.71), true: 1
# [Row 157] Rain predicted: 0 (conf: 0.66), true: 1
# [Row 158] Sprinkler predicted: 1 (conf: 0.52), true: 0
# [Row 161] Sprinkler predicted: 0 (conf: 0.50), true: 1
# [Row 161] Wet_Grass predicted: 0 (conf: 0.55), true: 1
# [Row 164] Sprinkler predicted: 1 (conf: 0.52), true: 0
# [Row 171] Sprinkler predicted: 0 (conf: 0.90), true: 1
# [Row 172] Sprinkler predicted: 1 (conf: 0.52), true: 0
# [Row 175] Sprinkler predicted: 1 (conf: 0.52), true: 0
# [Row 187] Cloudy predicted: 0 (conf: 0.69), true: 1
# [Row 188] Cloudy predicted: 1 (conf: 0.88), true: 0
# [Row 191] Cloudy predicted: 0 (conf: 0.56), true: 1
# [Row 194] Rain predicted: 0 (conf: 0.71), true: 1
# [Row 197] Cloudy predicted: 0 (conf: 0.71), true: 1
#
# Final Accuracy: 0.8155
# Average Confidence: 0.8357
# (0.8155339805825242, 0.8356569612798882)

# %%
data = "water"
evaluate_network(
    MODELS + f"{data}/{data}_complete.bif",
    DATA + f"{data}/test.csv",
    DATA + f"{data}/test_missing.csv",
    verbose=True
)
# Out:
# Evaluating: 100%|██████████| 2000/2000 [00:04<00:00, 471.93it/s]
# Mismatches (431):
# [Row 2] CKNN_12_30 predicted: 0 (conf: 0.35), true: 1
# [Row 2] CKNN_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 12] CKNN_12_30 predicted: 0 (conf: 0.80), true: 1
# [Row 13] C_NI_12_15 predicted: 1 (conf: 0.45), true: 2
# [Row 14] C_NI_12_15 predicted: 1 (conf: 0.67), true: 2
# [Row 20] CKNI_12_15 predicted: 1 (conf: 0.39), true: 2
# [Row 23] C_NI_12_45 predicted: 2 (conf: 0.50), true: 1
# [Row 35] CNOD_12_30 predicted: 0 (conf: 0.61), true: 1
# [Row 35] CKNN_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 36] CKNI_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 37] C_NI_12_00 predicted: 1 (conf: 0.40), true: 2
# [Row 37] CKNI_12_45 predicted: 0 (conf: 0.33), true: 2
# [Row 54] C_NI_12_15 predicted: 3 (conf: 0.37), true: 2
# [Row 57] CKNN_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 62] C_NI_12_45 predicted: 3 (conf: 0.60), true: 2
# [Row 64] CKNI_12_30 predicted: 1 (conf: 0.40), true: 0
# [Row 65] C_NI_12_30 predicted: 3 (conf: 0.48), true: 1
# [Row 76] CKNN_12_15 predicted: 0 (conf: 0.80), true: 1
# [Row 77] C_NI_12_30 predicted: 3 (conf: 0.46), true: 2
# [Row 89] CNOD_12_15 predicted: 0 (conf: 0.73), true: 1
# [Row 95] CKND_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 118] CNOD_12_45 predicted: 1 (conf: 0.64), true: 0
# [Row 122] CKND_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 123] CKNI_12_15 predicted: 1 (conf: 0.39), true: 2
# [Row 131] C_NI_12_30 predicted: 1 (conf: 0.48), true: 0
# [Row 143] CBODD_12_15 predicted: 2 (conf: 0.61), true: 1
# [Row 143] C_NI_12_45 predicted: 2 (conf: 0.50), true: 0
# [Row 153] C_NI_12_15 predicted: 3 (conf: 0.47), true: 2
# [Row 153] CKNI_12_45 predicted: 0 (conf: 0.33), true: 2
# [Row 160] CKND_12_45 predicted: 0 (conf: 0.33), true: 2
# [Row 165] CKNI_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 170] CKNI_12_15 predicted: 2 (conf: 0.63), true: 1
# [Row 172] C_NI_12_30 predicted: 1 (conf: 0.68), true: 2
# [Row 184] C_NI_12_30 predicted: 1 (conf: 0.45), true: 0
# [Row 194] CKNI_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 195] CKNI_12_30 predicted: 1 (conf: 0.40), true: 2
# [Row 199] CNON_12_45 predicted: 1 (conf: 0.97), true: 2
# [Row 203] CNOD_12_30 predicted: 0 (conf: 0.61), true: 1
# [Row 209] CKNI_12_15 predicted: 1 (conf: 0.38), true: 0
# [Row 210] C_NI_12_45 predicted: 1 (conf: 0.45), true: 0
# [Row 211] CNON_12_30 predicted: 0 (conf: 0.45), true: 1
# [Row 211] CNON_12_45 predicted: 2 (conf: 0.27), true: 1
# [Row 212] CKNN_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 223] CKNI_12_00 predicted: 1 (conf: 0.40), true: 0
# [Row 226] CKNI_12_15 predicted: 1 (conf: 0.39), true: 2
# [Row 228] C_NI_12_15 predicted: 3 (conf: 0.48), true: 2
# [Row 230] CKNN_12_15 predicted: 0 (conf: 0.81), true: 1
# [Row 238] CKND_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 241] CKNN_12_15 predicted: 0 (conf: 0.81), true: 1
# [Row 244] CKNI_12_45 predicted: 0 (conf: 0.33), true: 2
# [Row 248] C_NI_12_00 predicted: 0 (conf: 0.63), true: 1
# [Row 249] CKNI_12_30 predicted: 2 (conf: 0.64), true: 1
# [Row 249] CKND_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 254] CKNI_12_30 predicted: 1 (conf: 0.38), true: 2
# [Row 269] CNOD_12_45 predicted: 1 (conf: 0.64), true: 0
# [Row 271] CKNN_12_15 predicted: 0 (conf: 0.81), true: 1
# [Row 276] CKNI_12_45 predicted: 0 (conf: 0.33), true: 2
# [Row 284] CNOD_12_45 predicted: 1 (conf: 0.64), true: 0
# [Row 288] CNOD_12_15 predicted: 0 (conf: 0.73), true: 1
# [Row 289] C_NI_12_00 predicted: 1 (conf: 0.35), true: 2
# [Row 291] CKNI_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 296] CKND_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 302] CKNN_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 303] CKNI_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 312] CKNI_12_30 predicted: 1 (conf: 0.39), true: 2
# [Row 314] C_NI_12_00 predicted: 2 (conf: 0.42), true: 3
# [Row 320] CKNI_12_30 predicted: 2 (conf: 0.64), true: 1
# [Row 328] CNOD_12_15 predicted: 0 (conf: 0.73), true: 1
# [Row 332] C_NI_12_15 predicted: 3 (conf: 0.66), true: 2
# [Row 335] CKNN_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 340] CKND_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 341] CKND_12_45 predicted: 0 (conf: 0.33), true: 2
# [Row 343] CKNI_12_15 predicted: 1 (conf: 0.40), true: 2
# [Row 344] CKND_12_45 predicted: 0 (conf: 0.33), true: 2
# [Row 352] C_NI_12_00 predicted: 2 (conf: 0.47), true: 1
# [Row 353] CKND_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 358] CKNN_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 364] C_NI_12_15 predicted: 0 (conf: 0.73), true: 1
# [Row 367] CKNI_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 370] C_NI_12_00 predicted: 0 (conf: 0.63), true: 1
# [Row 375] CBODD_12_30 predicted: 1 (conf: 0.59), true: 2
# [Row 389] CKNI_12_00 predicted: 0 (conf: 0.70), true: 1
# [Row 395] CKNN_12_15 predicted: 0 (conf: 0.81), true: 1
# [Row 400] CKNN_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 409] CKNI_12_30 predicted: 1 (conf: 0.39), true: 0
# [Row 409] C_NI_12_45 predicted: 2 (conf: 0.50), true: 1
# [Row 411] CKNN_12_15 predicted: 0 (conf: 0.81), true: 1
# [Row 416] CKNI_12_15 predicted: 0 (conf: 0.70), true: 1
# [Row 418] CKNI_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 421] C_NI_12_30 predicted: 1 (conf: 0.47), true: 0
# [Row 425] C_NI_12_15 predicted: 1 (conf: 0.46), true: 2
# [Row 439] C_NI_12_30 predicted: 1 (conf: 0.46), true: 2
# [Row 444] C_NI_12_15 predicted: 3 (conf: 0.47), true: 2
# [Row 448] CKND_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 452] CKNI_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 456] CKNI_12_15 predicted: 2 (conf: 0.51), true: 1
# [Row 464] CKNI_12_30 predicted: 1 (conf: 0.39), true: 0
# [Row 467] CKNI_12_00 predicted: 2 (conf: 0.84), true: 1
# [Row 470] CKNN_12_15 predicted: 0 (conf: 0.80), true: 1
# [Row 483] CKNI_12_30 predicted: 2 (conf: 0.64), true: 1
# [Row 487] CKND_12_45 predicted: 0 (conf: 0.33), true: 2
# [Row 494] CKNI_12_30 predicted: 1 (conf: 0.39), true: 2
# [Row 497] C_NI_12_15 predicted: 3 (conf: 0.48), true: 2
# [Row 502] CKNI_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 510] CKNN_12_30 predicted: 1 (conf: 0.34), true: 0
# [Row 524] CKNI_12_15 predicted: 0 (conf: 0.67), true: 2
# [Row 526] CNOD_12_15 predicted: 0 (conf: 0.73), true: 1
# [Row 526] CKNI_12_30 predicted: 0 (conf: 0.68), true: 1
# [Row 534] CKNI_12_30 predicted: 0 (conf: 0.35), true: 2
# [Row 534] CKNI_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 535] CNOD_12_30 predicted: 0 (conf: 0.61), true: 1
# [Row 543] CKNI_12_30 predicted: 2 (conf: 0.63), true: 1
# [Row 544] CKNI_12_00 predicted: 1 (conf: 0.39), true: 0
# [Row 549] CKND_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 556] CKND_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 565] CNOD_12_15 predicted: 0 (conf: 0.74), true: 1
# [Row 582] CKNI_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 588] CKND_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 592] CKND_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 593] CKNI_12_15 predicted: 2 (conf: 0.55), true: 1
# [Row 596] CKNI_12_30 predicted: 1 (conf: 0.38), true: 0
# [Row 598] CKND_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 599] CKNI_12_30 predicted: 0 (conf: 0.68), true: 1
# [Row 607] CKNI_12_15 predicted: 1 (conf: 0.39), true: 2
# [Row 607] C_NI_12_45 predicted: 2 (conf: 0.50), true: 1
# [Row 613] CKND_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 622] CKNI_12_15 predicted: 0 (conf: 0.67), true: 1
# [Row 623] C_NI_12_00 predicted: 2 (conf: 0.51), true: 1
# [Row 624] CNOD_12_30 predicted: 1 (conf: 0.64), true: 0
# [Row 628] C_NI_12_45 predicted: 1 (conf: 0.55), true: 3
# [Row 647] CBODD_12_45 predicted: 2 (conf: 0.97), true: 3
# [Row 651] CKNI_12_00 predicted: 1 (conf: 0.39), true: 0
# [Row 656] C_NI_12_00 predicted: 1 (conf: 0.39), true: 2
# [Row 657] C_NI_12_00 predicted: 2 (conf: 0.48), true: 1
# [Row 669] CKND_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 675] CKNI_12_00 predicted: 1 (conf: 0.39), true: 0
# [Row 684] CKND_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 691] C_NI_12_30 predicted: 1 (conf: 0.47), true: 2
# [Row 691] CKND_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 703] CKNI_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 704] CKNN_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 705] C_NI_12_15 predicted: 0 (conf: 0.74), true: 1
# [Row 718] C_NI_12_30 predicted: 3 (conf: 0.47), true: 2
# [Row 721] C_NI_12_30 predicted: 1 (conf: 0.45), true: 0
# [Row 723] CKNI_12_30 predicted: 0 (conf: 0.67), true: 1
# [Row 730] C_NI_12_15 predicted: 1 (conf: 0.50), true: 0
# [Row 731] CNOD_12_45 predicted: 1 (conf: 0.54), true: 0
# [Row 733] CKNI_12_45 predicted: 0 (conf: 0.33), true: 2
# [Row 735] CKNI_12_30 predicted: 2 (conf: 0.63), true: 1
# [Row 740] CKNI_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 743] CKNI_12_00 predicted: 1 (conf: 0.39), true: 0
# [Row 768] C_NI_12_45 predicted: 2 (conf: 0.50), true: 3
# [Row 768] CKNI_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 786] C_NI_12_00 predicted: 2 (conf: 0.47), true: 3
# [Row 796] CKND_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 798] CKNI_12_15 predicted: 1 (conf: 0.38), true: 0
# [Row 801] C_NI_12_30 predicted: 1 (conf: 0.47), true: 2
# [Row 801] CNOD_12_30 predicted: 0 (conf: 0.61), true: 1
# [Row 803] CKNI_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 806] CKNN_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 814] C_NI_12_00 predicted: 0 (conf: 0.61), true: 2
# [Row 816] CKNI_12_30 predicted: 2 (conf: 0.65), true: 0
# [Row 820] CKND_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 823] C_NI_12_00 predicted: 3 (conf: 0.78), true: 2
# [Row 826] C_NI_12_15 predicted: 3 (conf: 0.48), true: 2
# [Row 830] CKNI_12_30 predicted: 1 (conf: 0.39), true: 2
# [Row 836] CKNI_12_15 predicted: 2 (conf: 0.65), true: 1
# [Row 836] C_NI_12_30 predicted: 1 (conf: 0.44), true: 0
# [Row 846] C_NI_12_00 predicted: 1 (conf: 0.40), true: 3
# [Row 846] CKNI_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 855] CKND_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 858] CKNI_12_00 predicted: 1 (conf: 0.39), true: 2
# [Row 862] C_NI_12_00 predicted: 1 (conf: 0.39), true: 2
# [Row 862] CKND_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 867] CNOD_12_30 predicted: 0 (conf: 0.66), true: 1
# [Row 870] CKNI_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 871] CKND_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 872] CKNN_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 881] C_NI_12_15 predicted: 1 (conf: 0.46), true: 2
# [Row 896] CKND_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 899] CKND_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 903] C_NI_12_30 predicted: 0 (conf: 0.49), true: 1
# [Row 916] CKNN_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 919] C_NI_12_15 predicted: 1 (conf: 0.47), true: 0
# [Row 919] CKNN_12_15 predicted: 0 (conf: 0.80), true: 1
# [Row 920] CKNI_12_30 predicted: 1 (conf: 0.39), true: 2
# [Row 923] C_NI_12_00 predicted: 3 (conf: 0.78), true: 2
# [Row 926] CKND_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 934] CKND_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 936] CKNN_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 937] CKNN_12_15 predicted: 0 (conf: 0.81), true: 1
# [Row 964] CKNI_12_15 predicted: 2 (conf: 0.53), true: 1
# [Row 967] CKNI_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 972] CKND_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 977] CKNN_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 980] CKNI_12_15 predicted: 0 (conf: 0.67), true: 1
# [Row 983] CNOD_12_15 predicted: 0 (conf: 0.73), true: 1
# [Row 983] CKNI_12_30 predicted: 2 (conf: 0.64), true: 1
# [Row 989] C_NI_12_00 predicted: 1 (conf: 0.39), true: 3
# [Row 990] C_NI_12_45 predicted: 0 (conf: 0.50), true: 2
# [Row 1002] CKNN_12_30 predicted: 0 (conf: 0.81), true: 1
# [Row 1004] CNOD_12_15 predicted: 0 (conf: 0.68), true: 1
# [Row 1005] CNOD_12_30 predicted: 0 (conf: 0.61), true: 1
# [Row 1017] CKND_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 1018] CKNI_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 1019] C_NI_12_15 predicted: 0 (conf: 0.73), true: 1
# [Row 1020] C_NI_12_30 predicted: 1 (conf: 0.45), true: 0
# [Row 1021] CKNN_12_15 predicted: 0 (conf: 0.81), true: 1
# [Row 1025] CKNI_12_15 predicted: 0 (conf: 0.50), true: 2
# [Row 1025] CKNI_12_30 predicted: 0 (conf: 0.69), true: 1
# [Row 1027] CKNI_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 1038] C_NI_12_00 predicted: 1 (conf: 0.39), true: 2
# [Row 1043] CKNN_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 1044] CKNN_12_15 predicted: 0 (conf: 0.79), true: 1
# [Row 1045] C_NI_12_45 predicted: 2 (conf: 0.50), true: 1
# [Row 1049] CKND_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 1061] CBODD_12_45 predicted: 2 (conf: 0.94), true: 1
# [Row 1071] CKNI_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 1074] CKNI_12_30 predicted: 0 (conf: 0.67), true: 1
# [Row 1079] C_NI_12_00 predicted: 2 (conf: 0.47), true: 3
# [Row 1079] CKNI_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 1085] CNOD_12_15 predicted: 0 (conf: 0.73), true: 1
# [Row 1119] C_NI_12_30 predicted: 2 (conf: 0.72), true: 1
# [Row 1120] C_NI_12_00 predicted: 0 (conf: 0.63), true: 1
# [Row 1120] CNOD_12_15 predicted: 0 (conf: 0.73), true: 1
# [Row 1124] CKNI_12_00 predicted: 1 (conf: 0.39), true: 0
# [Row 1125] CKND_12_30 predicted: 2 (conf: 0.96), true: 1
# [Row 1127] CKNI_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 1139] C_NI_12_30 predicted: 1 (conf: 0.48), true: 2
# [Row 1141] C_NI_12_30 predicted: 3 (conf: 0.46), true: 2
# [Row 1145] CKND_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 1148] CKNI_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 1148] CKND_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 1158] C_NI_12_15 predicted: 1 (conf: 0.48), true: 2
# [Row 1158] CKNI_12_15 predicted: 1 (conf: 0.39), true: 0
# [Row 1160] CKNI_12_15 predicted: 1 (conf: 0.38), true: 2
# [Row 1168] C_NI_12_00 predicted: 0 (conf: 0.63), true: 1
# [Row 1171] CKNN_12_15 predicted: 0 (conf: 0.80), true: 1
# [Row 1173] C_NI_12_45 predicted: 0 (conf: 0.50), true: 1
# [Row 1178] C_NI_12_45 predicted: 1 (conf: 0.55), true: 0
# [Row 1184] C_NI_12_00 predicted: 3 (conf: 0.71), true: 2
# [Row 1186] CKND_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 1188] C_NI_12_30 predicted: 1 (conf: 0.38), true: 2
# [Row 1189] CNOD_12_15 predicted: 0 (conf: 0.73), true: 1
# [Row 1191] CKND_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 1197] CKNI_12_30 predicted: 2 (conf: 0.84), true: 1
# [Row 1202] C_NI_12_15 predicted: 3 (conf: 0.37), true: 1
# [Row 1211] CKNI_12_15 predicted: 1 (conf: 0.38), true: 2
# [Row 1212] CKNI_12_15 predicted: 0 (conf: 0.70), true: 1
# [Row 1213] C_NI_12_30 predicted: 1 (conf: 0.46), true: 2
# [Row 1215] CKNI_12_15 predicted: 1 (conf: 0.39), true: 0
# [Row 1225] CKND_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 1235] CKNI_12_15 predicted: 2 (conf: 0.64), true: 1
# [Row 1235] CKND_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 1242] CKNI_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 1243] CKND_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 1251] CKNI_12_15 predicted: 0 (conf: 0.67), true: 1
# [Row 1251] C_NI_12_30 predicted: 0 (conf: 0.73), true: 1
# [Row 1260] CKNN_12_30 predicted: 1 (conf: 0.74), true: 0
# [Row 1261] CKND_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 1267] CKNI_12_00 predicted: 2 (conf: 0.63), true: 1
# [Row 1271] CKNI_12_30 predicted: 1 (conf: 0.38), true: 2
# [Row 1273] C_NI_12_15 predicted: 2 (conf: 0.72), true: 3
# [Row 1284] C_NI_12_30 predicted: 1 (conf: 0.67), true: 2
# [Row 1295] CBODN_12_45 predicted: 1 (conf: 0.94), true: 2
# [Row 1298] CKNI_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 1300] CKND_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 1309] CKNN_12_30 predicted: 0 (conf: 0.81), true: 1
# [Row 1311] CKNI_12_00 predicted: 2 (conf: 0.63), true: 1
# [Row 1314] CKND_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 1320] CKNI_12_00 predicted: 0 (conf: 0.35), true: 1
# [Row 1320] CKNI_12_15 predicted: 1 (conf: 0.40), true: 0
# [Row 1322] CKNI_12_45 predicted: 0 (conf: 0.33), true: 2
# [Row 1335] CKND_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 1350] CNON_12_45 predicted: 0 (conf: 0.25), true: 1
# [Row 1353] CKNI_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 1361] CKND_12_30 predicted: 0 (conf: 0.35), true: 1
# [Row 1361] CKND_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 1364] C_NI_12_30 predicted: 3 (conf: 0.38), true: 1
# [Row 1365] C_NI_12_45 predicted: 1 (conf: 0.55), true: 2
# [Row 1368] CKNN_12_15 predicted: 0 (conf: 0.80), true: 1
# [Row 1368] C_NI_12_30 predicted: 1 (conf: 0.67), true: 0
# [Row 1374] C_NI_12_30 predicted: 1 (conf: 0.49), true: 0
# [Row 1379] C_NI_12_45 predicted: 3 (conf: 0.60), true: 2
# [Row 1405] C_NI_12_15 predicted: 1 (conf: 0.38), true: 0
# [Row 1405] CKNI_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 1409] CBODN_12_45 predicted: 1 (conf: 0.99), true: 2
# [Row 1417] CKNI_12_15 predicted: 2 (conf: 0.66), true: 1
# [Row 1418] CKND_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 1419] CKNI_12_30 predicted: 2 (conf: 0.64), true: 1
# [Row 1425] CKNI_12_15 predicted: 0 (conf: 0.70), true: 1
# [Row 1438] CNOD_12_45 predicted: 1 (conf: 0.64), true: 0
# [Row 1440] CKNN_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 1441] C_NI_12_00 predicted: 1 (conf: 0.40), true: 0
# [Row 1443] CNOD_12_15 predicted: 0 (conf: 0.73), true: 1
# [Row 1445] C_NI_12_00 predicted: 3 (conf: 0.79), true: 2
# [Row 1446] C_NI_12_00 predicted: 2 (conf: 0.48), true: 3
# [Row 1446] CKNI_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 1451] CKND_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 1454] C_NI_12_00 predicted: 2 (conf: 0.48), true: 3
# [Row 1454] CKNN_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 1456] CKND_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 1459] CNOD_12_15 predicted: 0 (conf: 0.73), true: 1
# [Row 1475] CKNI_12_45 predicted: 0 (conf: 0.33), true: 2
# [Row 1478] CKNI_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 1480] CKNI_12_15 predicted: 2 (conf: 0.51), true: 1
# [Row 1481] C_NI_12_00 predicted: 2 (conf: 0.48), true: 1
# [Row 1485] CKND_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 1489] C_NI_12_15 predicted: 3 (conf: 0.48), true: 2
# [Row 1492] C_NI_12_00 predicted: 2 (conf: 0.48), true: 3
# [Row 1505] CKND_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 1506] C_NI_12_30 predicted: 2 (conf: 0.72), true: 3
# [Row 1506] CKND_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 1508] CKNN_12_15 predicted: 0 (conf: 0.81), true: 1
# [Row 1512] CKNI_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 1515] C_NI_12_00 predicted: 0 (conf: 0.65), true: 1
# [Row 1517] CKNI_12_45 predicted: 0 (conf: 0.33), true: 2
# [Row 1529] CKNN_12_15 predicted: 0 (conf: 0.80), true: 1
# [Row 1535] CNOD_12_15 predicted: 0 (conf: 0.73), true: 1
# [Row 1536] C_NI_12_45 predicted: 0 (conf: 0.50), true: 1
# [Row 1536] CKNI_12_45 predicted: 0 (conf: 0.33), true: 2
# [Row 1538] CKNI_12_45 predicted: 0 (conf: 0.33), true: 2
# [Row 1541] CKND_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 1552] CKNI_12_00 predicted: 1 (conf: 0.39), true: 0
# [Row 1553] CKNI_12_15 predicted: 1 (conf: 0.40), true: 2
# [Row 1555] CKNI_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 1559] CKND_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 1560] CKND_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 1563] CNOD_12_30 predicted: 0 (conf: 0.61), true: 1
# [Row 1567] C_NI_12_30 predicted: 1 (conf: 0.47), true: 0
# [Row 1569] CKNN_12_30 predicted: 0 (conf: 0.80), true: 1
# [Row 1571] C_NI_12_00 predicted: 3 (conf: 0.78), true: 1
# [Row 1575] CKNI_12_00 predicted: 1 (conf: 0.39), true: 2
# [Row 1580] CKNN_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 1581] CKND_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 1584] CKND_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 1591] CNOD_12_45 predicted: 1 (conf: 0.64), true: 0
# [Row 1598] CKNI_12_15 predicted: 0 (conf: 0.67), true: 1
# [Row 1604] CKNN_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 1608] CKNN_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 1616] CKNI_12_15 predicted: 1 (conf: 0.39), true: 2
# [Row 1616] CKNI_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 1621] CKND_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 1622] CKNN_12_30 predicted: 0 (conf: 0.80), true: 1
# [Row 1624] CKND_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 1629] C_NI_12_15 predicted: 1 (conf: 0.46), true: 2
# [Row 1630] CKND_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 1638] C_NI_12_00 predicted: 1 (conf: 0.39), true: 0
# [Row 1645] CKND_12_15 predicted: 2 (conf: 0.93), true: 1
# [Row 1648] C_NI_12_30 predicted: 1 (conf: 0.45), true: 2
# [Row 1649] CKNN_12_15 predicted: 0 (conf: 0.80), true: 1
# [Row 1649] CBODD_12_45 predicted: 1 (conf: 0.77), true: 2
# [Row 1650] CKNI_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 1650] CKNN_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 1653] CKNN_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 1654] CKNI_12_00 predicted: 1 (conf: 0.38), true: 2
# [Row 1658] CKND_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 1668] C_NI_12_00 predicted: 1 (conf: 0.39), true: 3
# [Row 1673] C_NI_12_15 predicted: 1 (conf: 0.35), true: 2
# [Row 1674] C_NI_12_15 predicted: 1 (conf: 0.44), true: 2
# [Row 1679] CKNI_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 1693] CKNI_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 1697] CKND_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 1698] CBODN_12_30 predicted: 1 (conf: 0.53), true: 2
# [Row 1700] CKND_12_30 predicted: 2 (conf: 0.93), true: 1
# [Row 1714] CKND_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 1717] CKNI_12_00 predicted: 0 (conf: 0.69), true: 1
# [Row 1720] C_NI_12_15 predicted: 1 (conf: 0.38), true: 2
# [Row 1724] CKNI_12_15 predicted: 0 (conf: 0.38), true: 1
# [Row 1734] CKNI_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 1738] C_NI_12_30 predicted: 1 (conf: 0.48), true: 0
# [Row 1739] C_NI_12_00 predicted: 2 (conf: 0.48), true: 1
# [Row 1742] CKNN_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 1747] C_NI_12_45 predicted: 0 (conf: 0.50), true: 1
# [Row 1748] CKNI_12_15 predicted: 0 (conf: 0.67), true: 1
# [Row 1751] CKNI_12_45 predicted: 0 (conf: 0.33), true: 2
# [Row 1753] CNOD_12_45 predicted: 1 (conf: 0.76), true: 0
# [Row 1767] CKND_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 1770] CKNI_12_00 predicted: 1 (conf: 0.39), true: 2
# [Row 1777] C_NI_12_45 predicted: 1 (conf: 0.55), true: 0
# [Row 1782] C_NI_12_15 predicted: 3 (conf: 0.46), true: 2
# [Row 1783] CKNI_12_00 predicted: 1 (conf: 0.39), true: 0
# [Row 1784] CNOD_12_30 predicted: 0 (conf: 0.61), true: 1
# [Row 1786] C_NI_12_30 predicted: 1 (conf: 0.47), true: 2
# [Row 1786] CKNI_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 1789] C_NI_12_15 predicted: 1 (conf: 0.67), true: 2
# [Row 1795] CKNN_12_15 predicted: 0 (conf: 0.79), true: 1
# [Row 1797] CNON_12_30 predicted: 2 (conf: 0.93), true: 1
# [Row 1799] C_NI_12_15 predicted: 1 (conf: 0.48), true: 0
# [Row 1801] CKNI_12_00 predicted: 1 (conf: 0.40), true: 0
# [Row 1805] C_NI_12_30 predicted: 1 (conf: 0.48), true: 0
# [Row 1812] C_NI_12_45 predicted: 1 (conf: 0.55), true: 2
# [Row 1821] CKNI_12_00 predicted: 1 (conf: 0.40), true: 2
# [Row 1821] C_NI_12_30 predicted: 3 (conf: 0.55), true: 1
# [Row 1824] C_NI_12_45 predicted: 0 (conf: 0.50), true: 1
# [Row 1827] CNOD_12_30 predicted: 0 (conf: 0.62), true: 1
# [Row 1832] CKNI_12_30 predicted: 1 (conf: 0.38), true: 0
# [Row 1833] CKNI_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 1836] CKNI_12_15 predicted: 2 (conf: 0.49), true: 1
# [Row 1837] C_NI_12_30 predicted: 1 (conf: 0.56), true: 0
# [Row 1847] C_NI_12_15 predicted: 1 (conf: 0.49), true: 0
# [Row 1848] CKND_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 1850] CKNN_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 1851] CKND_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 1858] CKNI_12_15 predicted: 1 (conf: 0.39), true: 0
# [Row 1860] CNOD_12_15 predicted: 0 (conf: 0.58), true: 1
# [Row 1866] C_NI_12_15 predicted: 1 (conf: 0.47), true: 0
# [Row 1867] C_NI_12_45 predicted: 2 (conf: 0.50), true: 3
# [Row 1869] C_NI_12_15 predicted: 1 (conf: 0.46), true: 2
# [Row 1873] CKNN_12_15 predicted: 0 (conf: 0.80), true: 1
# [Row 1875] CNOD_12_15 predicted: 0 (conf: 0.73), true: 1
# [Row 1879] C_NI_12_15 predicted: 1 (conf: 0.46), true: 3
# [Row 1889] C_NI_12_30 predicted: 1 (conf: 0.37), true: 2
# [Row 1901] CKNI_12_45 predicted: 0 (conf: 0.33), true: 2
# [Row 1917] CKND_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 1929] C_NI_12_00 predicted: 2 (conf: 0.47), true: 0
# [Row 1929] CNOD_12_15 predicted: 0 (conf: 0.73), true: 1
# [Row 1930] CKNI_12_30 predicted: 2 (conf: 0.64), true: 1
# [Row 1933] CKND_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 1933] CKNN_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 1934] CKNI_12_30 predicted: 1 (conf: 0.39), true: 0
# [Row 1941] CBODD_12_15 predicted: 1 (conf: 0.53), true: 2
# [Row 1941] CKNI_12_45 predicted: 0 (conf: 0.33), true: 2
# [Row 1942] CKNI_12_00 predicted: 1 (conf: 0.40), true: 2
# [Row 1946] C_NI_12_30 predicted: 3 (conf: 0.46), true: 2
# [Row 1950] CKNI_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 1958] C_NI_12_15 predicted: 1 (conf: 0.68), true: 2
# [Row 1967] CKND_12_45 predicted: 0 (conf: 0.33), true: 1
# [Row 1969] C_NI_12_30 predicted: 1 (conf: 0.37), true: 3
# [Row 1990] CKNI_12_30 predicted: 0 (conf: 0.68), true: 1
# [Row 1996] CNON_12_30 predicted: 2 (conf: 0.93), true: 1
#
# Final Accuracy: 0.7884
# Average Confidence: 0.7783
# (0.7884143348060874, 0.7783274548616614)
